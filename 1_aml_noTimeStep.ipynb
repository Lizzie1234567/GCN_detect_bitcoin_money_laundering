# %% [markdown]
# <a href="https://colab.research.google.com/github/Lizzie1234567/GCN_detect_bitcoin_money_laundering/blob/main/1_aml_noTimeStep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Anti Money Laundering in Elliptic Blockchain dataset

# %% [markdown]
# Project outline
#
# *   Implement the paper
# *   Change architectures from Torch to Keras
# *   Develop the tracking algorithm
# *   Develop a GAT model and compare it to the GCN
# *   Compare all the results

# %% [markdown]
# ## Prepare and inspect data

# %% [markdown]
# ### imports

# %%
import os
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import sklearn

# %% [markdown]
# ### data retrival

# %%
# Prepare a dataFrame for results, used in the last part for a general comparison
compare = pd.DataFrame(columns=['model','Precision','Recall', 'F1 Score','M.A F1 Score'])

# %%
# zip_file = keras.utils.get_file(
#     fname="elliptic.zip",
#     origin="https://storage.googleapis.com/kaggle-data-sets/284040/584717/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20211206%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20211206T132009Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...",
#     extract=True,
# )
# print(zip_file)

# %%
# cd /root/.keras/datasets/elliptic_bitcoin_dataset

# %%
# os.environ['KAGGLE_USERNAME'] = "lizzylin067@gmail.com" # username from the json file
# os.environ['KAGGLE_KEY'] = "Kaggle067!" # key from the json file


# !kaggle datasets download -d ellipticco/elliptic-data-set
# !unzip elliptic-data-set.zip
# !mkdir elliptic_bitcoin_dataset_cont

import os

os.environ['KAGGLE_USERNAME'] = "henry067"
os.environ['KAGGLE_KEY'] = "0d6098f677227f95b88639d89e049217"

# !kaggle datasets download -d ellipticco/elliptic-data-set

# Unzip the file if it exists
if os.path.exists("elliptic-data-set.zip"):
    # !unzip elliptic-data-set.zip

# Create the directory if it doesn't exist
if not os.path.exists("elliptic_bitcoin_dataset_cont"):
    os.makedirs("elliptic_bitcoin_dataset_cont")
# Out:
# Downloading elliptic-data-set.zip to /content
#  97% 142M/146M [00:05<00:00, 28.0MB/s]
# 100% 146M/146M [00:05<00:00, 27.8MB/s]
# Archive:  elliptic-data-set.zip
#   inflating: elliptic_bitcoin_dataset/elliptic_txs_classes.csv
#   inflating: elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv
#   inflating: elliptic_bitcoin_dataset/elliptic_txs_features.csv

# %%
edges = pd.read_csv("elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv")
features = pd.read_csv("elliptic_bitcoin_dataset/elliptic_txs_features.csv",header=None)
classes = pd.read_csv("elliptic_bitcoin_dataset/elliptic_txs_classes.csv")

# %%
print(edges.shape)
print(features.shape)
print(classes.shape)
# Out:
# (234355, 2)
# (203769, 167)
# (203769, 2)

# %% [markdown]
# ### data preparation

# %%
#name all the features
tx_features = ["tx_feat_"+str(i) for i in range(2,95)]
agg_features = ["agg_feat_"+str(i) for i in range(1,73)]
features.columns = ["txId","time_step"] + tx_features + agg_features

#merge features and classes
features = pd.merge(features,classes,left_on="txId",right_on="txId",how='left')
features['class'] = features['class'].apply(lambda x: 0 if x == "unknown" else x)
features['class'] = features['class'].apply(lambda x: 1 if x == '1' else x)
features['class'] = features['class'].apply(lambda x: 2 if x == '2' else x)

# %%
features['class'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### swap the index
# for easier of use, we change the TxId identifier for the integer index. This simply many of the following considerations

# %%
class_values = sorted(features["class"].unique())
#we create a new index by sorting the tx_ids and assign to it a number
features_idx = {name: idx for idx, name in enumerate(sorted(features["txId"].unique()))}

# we then apply this new ids to all te data frames
# this helps a lot in computing the adjency matrix, having the ids as the index.
features["txId"] = features["txId"].apply(lambda name: features_idx[name])
edges["txId1"] = edges["txId1"].apply(lambda name: features_idx[name])
edges["txId2"] = edges["txId2"].apply(lambda name: features_idx[name])

# %% [markdown]
# ## The tracker
# The tracker is a function thats able to build the connected graph of a given transaction, displaying the graph, and compare it to the classified one.
# It can be used to look for particular clusters, for example the biggest connected graph, or it can be used to track a specific transaction.

# %% [markdown]
# ### the tracking function

# %%
# The tracker function recursively scans the network looking for the connected group to a given transaction.
# the deep levels represent the amount of recursive iterations it computes

def tracker(deep_levels, seed, edges):
  tmp = {seed}
  keep = set()
  counter = 0

  for i in range(deep_levels):
    for j in tmp:
      counter = counter + 1
      one = edges[edges['txId1'] == j]
      #add first
      tmp = set.union(tmp,set(one['txId2'].iloc[:]))

      two = edges[edges['txId2'] == j]
      #add second
      tmp = set.union(tmp,set(two['txId1'].iloc[:]))
      # check if connected group is empty
      if(len(one) == 0 & len(two) == 0):
          edgeList = edges[edges['txId1'].isin(keep)]
          return keep,edgeList,counter,True

      keep.add(j)
      tmp.remove(j)

  edgeList = edges[edges['txId1'].isin(keep)]
  return keep,edgeList,counter,False

# %%
def get_random_illicit(features):
  # get a random illicit transaction
  randomIllicit = features[features["class"] == 1].sample(1)["txId"]
  seed = randomIllicit.to_numpy()[0]
  # define the final DF containg the cluster
  return seed

# %%
def get_random_licit(features):
  # get a random illicit transaction
  randomLicit = features[features["class"] == 2].sample(1)["txId"]
  seed = randomLicit.to_numpy()[0]
  # define the final DF containg the cluster
  return seed

# %% [markdown]
# ### Plot an example graph

# %%
deep_levels = 20
keep = {}
tries = 0
minimum_nodes = 50

while(len(keep) < minimum_nodes):
  seed = get_random_illicit(features)
  keep,edgeList,counter,complete = tracker(deep_levels,seed,edges)
  tries = tries + 1

print("is the graph complete: ",complete)
print("iterations-> ",counter)
print("transactions found->",len(keep))
print("seed : ",seed)
print("seed tried:", tries)
print("transactions : \n")

print(edgeList)
# Out:
# is the graph complete:  True
# iterations->  85
# transactions found-> 83
# seed :  102555
# seed tried: 46
# transactions :
#
#          txId1   txId2
# 135766  102559  102542
# 135804  102554  102542
# 135820  102657  104040
# 135887  102580  102542
# 135931  102685  102684
# ...        ...     ...
# 140024  102583  102542
# 140085  102579  102542
# 140121  102557  102542
# 140179  102560  102542
# 140220  102923  104040
#
# [96 rows x 2 columns]

# %%
plt.figure(figsize=(10, 10))
import networkx as nx
transaction_graph = nx.from_pandas_edgelist(edgeList,source='txId1', target='txId2')
#transaction_type = features[features["txId"].isin(list(transaction_graph.nodes))]["class"]
transaction_type = features[features["txId"].isin(list(transaction_graph.nodes))]["class"]
transaction_type = transaction_type.apply(lambda x: 'gray' if x == 0 else x)
transaction_type = transaction_type.apply(lambda x: 'red' if x == 1 else x)
transaction_type = transaction_type.apply(lambda x: 'green' if x == 2 else x)
nx.draw_spring(transaction_graph,node_size=50, node_color=list(transaction_type),width=1)

# %% [markdown]
# Example of the connected group starting from 15292

# %% [markdown]
# ## Classification

# %% [markdown]
# ### select only the known part

# %%
# helper function
def check(name):
  if(name in unique):
    return name
  else :
    return -1

# %%
# get the features of the known transactions
features_known = features[features['class'] != 0 ]
features_unknown = features[features['class'] == 0 ]
edges_known = edges.copy()

# remove from the edges DF all the entries that mentions the unknown transactions
unique = features_known['txId'].unique()
edges_known["txId1"] = edges["txId1"].apply(lambda name: check(name))
edges_known["txId2"] = edges["txId2"].apply(lambda name: check(name))

edges_known = edges_known[edges_known["txId1"] != -1 ]
edges_known = edges_known[edges_known["txId2"] != -1 ]

print(edges_known.shape)
print(features.shape)
print(features_known.shape)
print(features_unknown.shape)
# Out:
# (36624, 2)
# (203769, 168)
# (46564, 168)
# (157205, 168)

# %% [markdown]
# ### split the data in train and test

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV

# %%
#Split the data, with the aggregated features

X = features_known[tx_features+agg_features]
y = features_known['class']
# this is important
y = y.apply(lambda x: 0 if x == 2 else 1 )
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=117,shuffle=True)
print("X_train shape",X_train.shape)
print("X_test shape",X_test.shape)
print("y_train shape",y_train.shape)
print("y_test shape",y_test.shape)
# Out:
# X_train shape (32594, 165)
# X_test shape (13970, 165)
# y_train shape (32594,)
# y_test shape (13970,)

# %%
#Split the data, without the aggregated features

X_noAgg = features_known[tx_features]
y_noAgg = features_known['class']
# this is important
y_noAgg = y_noAgg.apply(lambda x: 0 if x == 2 else 1 )
X_train_noAgg, X_test_noAgg, y_train_noAgg, y_test_noAgg = train_test_split(X_noAgg,y_noAgg,test_size=0.3,random_state=117,shuffle=True)
print("X_train shape",X_train_noAgg.shape)
print("X_test shape",X_test_noAgg.shape)
print("y_train shape",y_train_noAgg.shape)
print("y_test shape",y_test_noAgg.shape)
# Out:
# X_train shape (32594, 93)
# X_test shape (13970, 93)
# y_train shape (32594,)
# y_test shape (13970,)

# %% [markdown]
# ### Classification with Random Forest and Logistic Regression

# %% [markdown]
# The classification is done for both classifiers with and without aggregated features

# %%
clf = RandomForestClassifier(n_estimators=50, max_depth=100,random_state=15).fit(X_train_noAgg,y_train_noAgg)
preds = clf.predict(X_test_noAgg)
prec,rec,f1,num = precision_recall_fscore_support(y_test_noAgg,preds, average=None)
name = "Random Forest Classifier (tx)"
print(name)
print("Precision:%.3f \nRecall:%.3f \nF1 Score:%.3f"%(prec[1],rec[1],f1[1]))
micro_f1 = f1_score(y_test_noAgg,preds,average='micro')
print("Micro-Average F1 Score:",np.round(micro_f1,3))
# Out:
# Random Forest Classifier (tx)
# Precision:0.981
# Recall:0.854
# F1 Score:0.913
# Micro-Average F1 Score: 0.985

# %%
compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)
# Out:
# <ipython-input-85-5fee8f128f02>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)

# %%
clf = RandomForestClassifier(n_estimators=50, max_depth=100,random_state=15).fit(X_train,y_train)
preds = clf.predict(X_test)
prec,rec,f1,num = precision_recall_fscore_support(y_test,preds, average=None)
name = "Random Forest Classifier (tx + agg)"
print("Random Forest Classifier (tx + agg)")
print("Precision:%.3f \nRecall:%.3f \nF1 Score:%.3f"%(prec[1],rec[1],f1[1]))
micro_f1 = f1_score(y_test,preds,average='micro')
print("Micro-Average F1 Score:",micro_f1)
# Out:
# Random Forest Classifier (tx + agg)
# Precision:0.994
# Recall:0.888
# F1 Score:0.938
# Micro-Average F1 Score: 0.988976377952756

# %%
compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)
# Out:
# <ipython-input-87-5fee8f128f02>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)

# %%
reg = LogisticRegression(max_iter=10000).fit(X_train_noAgg,y_train_noAgg)
preds = reg.predict(X_test_noAgg)
prec,rec,f1,num = precision_recall_fscore_support(y_test_noAgg,preds, average=None)
name = "Logistic Regression (tx)"
print("Logistic Regression (tx)")
print("Precision:%.3f \nRecall:%.3f \nF1 Score:%.3f"%(prec[1],rec[1],f1[1]))
micro_f1 = f1_score(y_test_noAgg,preds,average='micro')
print("Micro-Average F1 Score:",micro_f1)
# Out:
# Logistic Regression (tx)
# Precision:0.910
# Recall:0.725
# F1 Score:0.807
# Micro-Average F1 Score: 0.9672870436649964

# %%
compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)
# Out:
# <ipython-input-89-5fee8f128f02>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)

# %%
reg = LogisticRegression(max_iter=10000).fit(X_train,y_train)
preds = reg.predict(X_test)
prec,rec,f1,num = precision_recall_fscore_support(y_test,preds, average=None)
name = "Logistic Regression (tx + agg)"
print("Logistic Regression (tx + agg)")
print("Precision:%.3f \nRecall:%.3f \nF1 Score:%.3f"%(prec[1],rec[1],f1[1]))
micro_f1 = f1_score(y_test,preds,average='micro')
print("Micro-Average F1 Score:",micro_f1)
# Out:
# Logistic Regression (tx + agg)
# Precision:0.848
# Recall:0.791
# F1 Score:0.819
# Micro-Average F1 Score: 0.9669291338582677

# %%
compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)
# Out:
# <ipython-input-91-5fee8f128f02>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)

# %% [markdown]
# ### Classify the unknown transactions

# %%
X = features_unknown[tx_features+agg_features]
preds = pd.DataFrame(clf.predict(X),columns=['class'])
features_unknown = features_unknown[['txId']+tx_features+agg_features].join(preds)
features_unknown['class'] = features_unknown['class'].apply(lambda x: 2 if x==0 else 1)
features_classified = features_known.append(features_unknown)
# Out:
# <ipython-input-92-aa0d6e91674b>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_classified = features_known.append(features_unknown)

# %% [markdown]
# Exploring the distribution of classes in the unknown part. We see there is a big change from the 9 to 1 in the known part to the 73 to 26 in the classified part of the network.
# This is because the proposal of this paper is based around the idea of training with the past for classifiying the future.
# This choice is controversial, but for comparative purpose it is mantained troughout the following study.

# %%
features_unknown['class'].hist()
features_unknown['class'].value_counts(normalize=True) * 100
# Out:
# 2    73.773735
# 1    26.226265
# Name: class, dtype: float64

# %%
features_known['class'].hist()
features_known['class'].value_counts(normalize=True) * 100
# Out:
# 2    90.239241
# 1     9.760759
# Name: class, dtype: float64

# %% [markdown]
# ## Using the tracker function

# %% [markdown]
# ### find a connected network we intend to inspect

# %%
deep_levels = 10
keep = {}
tries = 0
minimum_nodes = 40

while(len(keep) < minimum_nodes):
  seed = get_random_illicit(features)
  keep,edgeList,counter,complete = tracker(deep_levels,seed,edges)
  tries = tries + 1

print("is the graph complete: ",complete)
print("iterations-> ",counter)
print("transactions found->",len(keep))
print("seed : ",seed)
print("seed tried:", tries)
print("transactions : \n")

print(edgeList)
# Out:
# is the graph complete:  True
# iterations->  153
# transactions found-> 151
# seed :  187794
# seed tried: 11
# transactions :
#
#          txId1   txId2
# 146023  187157  188922
# 146107  187503  188922
# 146205  187467  188922
# 146278  187136  188922
# 146355  188233  188922
# ...        ...     ...
# 150610  187819  188922
# 150623  188438  188922
# 150652  187846  188922
# 150713  188942  188922
# 150777  188418  188518
#
# [153 rows x 2 columns]

# %%
plt.figure(figsize=(10, 10))
import networkx as nx
transaction_graph = nx.from_pandas_edgelist(edgeList,source='txId1', target='txId2')
transaction_type = features[features["txId"].isin(list(transaction_graph.nodes))]["class"].sort_index()
transaction_type = transaction_type.apply(lambda x: 'gray' if x == 0 else x)
transaction_type = transaction_type.apply(lambda x: 'red' if x == 1 else x)
transaction_type = transaction_type.apply(lambda x: 'green' if x == 2 else x)
my_pos = nx.spring_layout(transaction_graph, seed = 100)
nx.draw(transaction_graph,node_size=50, pos=my_pos,node_color=list(transaction_type),width=1)

# %% [markdown]
# ### check the classified results

# %%
plt.figure(figsize=(10, 10))
import networkx as nx
transaction_graph = nx.from_pandas_edgelist(edgeList,source='txId1', target='txId2')
transaction_type = features_classified[features_classified["txId"].isin(list(transaction_graph.nodes))]["class"].sort_index()
transaction_type = transaction_type.apply(lambda x: 'gray' if x == 0 else x)
transaction_type = transaction_type.apply(lambda x: 'red' if x == 1 else x)
transaction_type = transaction_type.apply(lambda x: 'green' if x == 2 else x)
my_pos = nx.spring_layout(transaction_graph, seed = 100)
nx.draw(transaction_graph,node_size=50, pos=my_pos,node_color=list(transaction_type),width=1)

# %% [markdown]
# ## Classification with dense neural networks

# %% [markdown]
# Optimizing the model proved to be very difficult. I think that the problem relies in the time_step based training approach, whic challenges the worthiness of the validation set, and the training set itself.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow import keras

# %%
# Quick function for printing history
def print_learning_curves(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    ax1.plot(history.history["loss"])
    ax1.plot(history.history["val_loss"])
    ax1.legend(["train", "test"], loc="upper right")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")

    ax2.plot(history.history["acc"])
    ax2.plot(history.history["val_acc"])
    ax2.legend(["train", "test"], loc="upper right")
    ax2.set_xlabel("Epochs")
    ax2.set_ylabel("Accuracy")
    plt.show()

# %%
# Parametric feed forward function
def create_ffn(hidden_units, dropout_rate, name=None):
    fnn_layers = []
    seq = keras.Sequential(name=name)

    for units in hidden_units:
        # batch normalization layer
        seq.add(layers.BatchNormalization())
        # add a dropout layer
        seq.add(layers.Dropout(dropout_rate))
        # and finally the dense part
        seq.add(layers.Dense(units, activation=tf.nn.gelu))

    return seq

# %%
def create_baseline_model(hidden_units, num_classes, dropout_rate=0.2):
    inputs = layers.Input(shape=(num_features,), name="input_features")
    x = create_ffn(hidden_units, dropout_rate, name=f"ffn_block1")(inputs)
    for block_idx in range(4):
        # Create an FFN block.
        x1 = create_ffn(hidden_units, dropout_rate, name=f"ffn_block{block_idx + 2}")(x)
        # Add skip connection.
        x = layers.Add(name=f"skip_connection{block_idx + 2}")([x, x1])
    # Compute logits.
    logits = layers.Dense(num_classes, name="logits")(x)
    # Create the model.
    return keras.Model(inputs=inputs, outputs=logits, name="baseline")

# %% [markdown]
# ### Training with only tx_features

# %%
# The executoion of the code here is redundant
# to avoid possible inconsistencies in re-executing the cell
X_noAgg = features_known[tx_features]
y_noAgg = features_known['class']
y_noAgg = y_noAgg.apply(lambda x: 0 if x == 2 else 1 )
X_train_noAgg, X_test_noAgg, y_train_noAgg, y_test_noAgg = train_test_split(X_noAgg,y_noAgg,test_size=0.3,random_state=117,shuffle=True)
#Create a validation set
X_train_noAgg, X_val_noAgg, y_train_noAgg, y_val_noAgg = train_test_split(X_train_noAgg,y_train_noAgg,test_size=0.15,random_state=117,shuffle=True)
print("X_train shape",X_train_noAgg.shape)
print("X_test shape",X_test_noAgg.shape)
print("X_val shape",X_val_noAgg.shape)
print("X_test shape",X_test_noAgg.shape)
print("y_train shape",y_train_noAgg.shape)
print("y_test shape",y_test_noAgg.shape)
print("y_val shape",y_val_noAgg.shape)
# Out:
# X_train shape (27704, 93)
# X_test shape (13970, 93)
# X_val shape (4890, 93)
# X_test shape (13970, 93)
# y_train shape (27704,)
# y_test shape (13970,)
# y_val shape (4890,)

# %%
hidden_units = [90]
learning_rate = 0.001
dropout_rate = 0.3
num_epochs = 200
batch_size = 256

# %%
feature_names = features_known[tx_features].columns
num_features = len(feature_names)
num_classes = len(np.unique(y_train))

# %%
baseline_model = create_baseline_model(hidden_units, 2, dropout_rate)
baseline_model.summary()
# Out:
# Model: "baseline"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_features (InputLayer  [(None, 93)]                 0         []
#  )
#
#  ffn_block1 (Sequential)     (None, 90)                   8832      ['input_features[0][0]']
#
#  ffn_block2 (Sequential)     (None, 90)                   8550      ['ffn_block1[0][0]']
#
#  skip_connection2 (Add)      (None, 90)                   0         ['ffn_block1[0][0]',
#                                                                      'ffn_block2[0][0]']
#
#  ffn_block3 (Sequential)     (None, 90)                   8550      ['skip_connection2[0][0]']
#
#  skip_connection3 (Add)      (None, 90)                   0         ['skip_connection2[0][0]',
#                                                                      'ffn_block3[0][0]']
#
#  ffn_block4 (Sequential)     (None, 90)                   8550      ['skip_connection3[0][0]']
#
#  skip_connection4 (Add)      (None, 90)                   0         ['skip_connection3[0][0]',
#                                                                      'ffn_block4[0][0]']
#
#  ffn_block5 (Sequential)     (None, 90)                   8550      ['skip_connection4[0][0]']
#
#  skip_connection5 (Add)      (None, 90)                   0         ['skip_connection4[0][0]',
#                                                                      'ffn_block5[0][0]']
#
#  logits (Dense)              (None, 2)                    182       ['skip_connection5[0][0]']
#
# ==================================================================================================
# Total params: 43214 (168.80 KB)
# Trainable params: 42308 (165.27 KB)
# Non-trainable params: 906 (3.54 KB)
# __________________________________________________________________________________________________

# %%
# Compile the model.
baseline_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)
# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=30, restore_best_weights=True
)
# Fit the model.
history = baseline_model.fit(
    x=X_train_noAgg,
    y=y_train_noAgg,
    epochs=num_epochs,
    batch_size=batch_size,
    validation_data = (X_val_noAgg,y_val_noAgg),
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/200
# 109/109 [==============================] - 7s 15ms/step - loss: 0.4196 - acc: 0.8551 - val_loss: 0.1934 - val_acc: 0.9027
# Epoch 2/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1941 - acc: 0.9338 - val_loss: 0.1555 - val_acc: 0.9646
# Epoch 3/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1720 - acc: 0.9439 - val_loss: 0.1434 - val_acc: 0.9656
# Epoch 4/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1583 - acc: 0.9488 - val_loss: 0.1377 - val_acc: 0.9673
# Epoch 5/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1518 - acc: 0.9517 - val_loss: 0.1296 - val_acc: 0.9683
# Epoch 6/200
# 109/109 [==============================] - 2s 14ms/step - loss: 0.1430 - acc: 0.9545 - val_loss: 0.1337 - val_acc: 0.9693
# Epoch 7/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.1418 - acc: 0.9552 - val_loss: 0.1286 - val_acc: 0.9689
# Epoch 8/200
# 109/109 [==============================] - 2s 14ms/step - loss: 0.1350 - acc: 0.9571 - val_loss: 0.1274 - val_acc: 0.9683
# Epoch 9/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1317 - acc: 0.9594 - val_loss: 0.1207 - val_acc: 0.9695
# Epoch 10/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.1261 - acc: 0.9605 - val_loss: 0.1306 - val_acc: 0.9685
# Epoch 11/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1281 - acc: 0.9593 - val_loss: 0.1155 - val_acc: 0.9703
# Epoch 12/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.1236 - acc: 0.9611 - val_loss: 0.1200 - val_acc: 0.9703
# Epoch 13/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1223 - acc: 0.9622 - val_loss: 0.1126 - val_acc: 0.9703
# Epoch 14/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1217 - acc: 0.9620 - val_loss: 0.1312 - val_acc: 0.9699
# Epoch 15/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1188 - acc: 0.9631 - val_loss: 0.1363 - val_acc: 0.9689
# Epoch 16/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.1168 - acc: 0.9640 - val_loss: 0.1122 - val_acc: 0.9708
# Epoch 17/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1167 - acc: 0.9654 - val_loss: 0.1200 - val_acc: 0.9703
# Epoch 18/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1148 - acc: 0.9641 - val_loss: 0.1063 - val_acc: 0.9708
# Epoch 19/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1134 - acc: 0.9642 - val_loss: 0.1142 - val_acc: 0.9687
# Epoch 20/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1128 - acc: 0.9653 - val_loss: 0.1650 - val_acc: 0.9076
# Epoch 21/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.1120 - acc: 0.9659 - val_loss: 0.1174 - val_acc: 0.9710
# Epoch 22/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.1082 - acc: 0.9666 - val_loss: 0.1136 - val_acc: 0.9703
# Epoch 23/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1078 - acc: 0.9664 - val_loss: 0.1197 - val_acc: 0.9708
# Epoch 24/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.1107 - acc: 0.9660 - val_loss: 0.1090 - val_acc: 0.9712
# Epoch 25/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.1045 - acc: 0.9666 - val_loss: 0.1326 - val_acc: 0.9703
# Epoch 26/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.1065 - acc: 0.9668 - val_loss: 0.1111 - val_acc: 0.9714
# Epoch 27/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1091 - acc: 0.9660 - val_loss: 0.1024 - val_acc: 0.9701
# Epoch 28/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1040 - acc: 0.9671 - val_loss: 0.1005 - val_acc: 0.9708
# Epoch 29/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1056 - acc: 0.9666 - val_loss: 0.1030 - val_acc: 0.9701
# Epoch 30/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1020 - acc: 0.9690 - val_loss: 0.1208 - val_acc: 0.9699
# Epoch 31/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1025 - acc: 0.9681 - val_loss: 0.1085 - val_acc: 0.9712
# Epoch 32/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.1004 - acc: 0.9690 - val_loss: 0.1267 - val_acc: 0.9691
# Epoch 33/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0984 - acc: 0.9685 - val_loss: 0.1197 - val_acc: 0.9697
# Epoch 34/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.1004 - acc: 0.9687 - val_loss: 0.1179 - val_acc: 0.9710
# Epoch 35/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1008 - acc: 0.9687 - val_loss: 0.1104 - val_acc: 0.9706
# Epoch 36/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0976 - acc: 0.9699 - val_loss: 0.1127 - val_acc: 0.9701
# Epoch 37/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0972 - acc: 0.9690 - val_loss: 0.1116 - val_acc: 0.9714
# Epoch 38/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0988 - acc: 0.9689 - val_loss: 0.0975 - val_acc: 0.9718
# Epoch 39/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0973 - acc: 0.9694 - val_loss: 0.1120 - val_acc: 0.9697
# Epoch 40/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0987 - acc: 0.9677 - val_loss: 0.1408 - val_acc: 0.9607
# Epoch 41/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0961 - acc: 0.9699 - val_loss: 0.1416 - val_acc: 0.9380
# Epoch 42/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.0973 - acc: 0.9689 - val_loss: 0.1263 - val_acc: 0.9648
# Epoch 43/200
# 109/109 [==============================] - 2s 14ms/step - loss: 0.0974 - acc: 0.9696 - val_loss: 0.1145 - val_acc: 0.9703
# Epoch 44/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0947 - acc: 0.9691 - val_loss: 0.1318 - val_acc: 0.9675
# Epoch 45/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0955 - acc: 0.9688 - val_loss: 0.1123 - val_acc: 0.9706
# Epoch 46/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0988 - acc: 0.9691 - val_loss: 0.1597 - val_acc: 0.9106
# Epoch 47/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0954 - acc: 0.9693 - val_loss: 0.1336 - val_acc: 0.9464
# Epoch 48/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0948 - acc: 0.9703 - val_loss: 0.1036 - val_acc: 0.9706
# Epoch 49/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0929 - acc: 0.9701 - val_loss: 0.1011 - val_acc: 0.9718
# Epoch 50/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0932 - acc: 0.9706 - val_loss: 0.1042 - val_acc: 0.9710
# Epoch 51/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0926 - acc: 0.9705 - val_loss: 0.1194 - val_acc: 0.9697
# Epoch 52/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0912 - acc: 0.9711 - val_loss: 0.1008 - val_acc: 0.9712
# Epoch 53/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0931 - acc: 0.9698 - val_loss: 0.1027 - val_acc: 0.9706
# Epoch 54/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0932 - acc: 0.9699 - val_loss: 0.1088 - val_acc: 0.9706
# Epoch 55/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0893 - acc: 0.9716 - val_loss: 0.1425 - val_acc: 0.9315
# Epoch 56/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0925 - acc: 0.9706 - val_loss: 0.1325 - val_acc: 0.9630
# Epoch 57/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0916 - acc: 0.9703 - val_loss: 0.1168 - val_acc: 0.9699
# Epoch 58/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0902 - acc: 0.9710 - val_loss: 0.1057 - val_acc: 0.9710
# Epoch 59/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.0916 - acc: 0.9708 - val_loss: 0.0969 - val_acc: 0.9710
# Epoch 60/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0882 - acc: 0.9704 - val_loss: 0.1309 - val_acc: 0.9699
# Epoch 61/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0902 - acc: 0.9708 - val_loss: 0.0935 - val_acc: 0.9716
# Epoch 62/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0896 - acc: 0.9720 - val_loss: 0.1007 - val_acc: 0.9722
# Epoch 63/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.0910 - acc: 0.9706 - val_loss: 0.1016 - val_acc: 0.9718
# Epoch 64/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0884 - acc: 0.9713 - val_loss: 0.1096 - val_acc: 0.9710
# Epoch 65/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0868 - acc: 0.9721 - val_loss: 0.1015 - val_acc: 0.9714
# Epoch 66/200
# 109/109 [==============================] - 2s 15ms/step - loss: 0.0906 - acc: 0.9709 - val_loss: 0.1078 - val_acc: 0.9703
# Epoch 67/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.0877 - acc: 0.9718 - val_loss: 0.1104 - val_acc: 0.9699
# Epoch 68/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0886 - acc: 0.9710 - val_loss: 0.1077 - val_acc: 0.9697
# Epoch 69/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0875 - acc: 0.9723 - val_loss: 0.0929 - val_acc: 0.9706
# Epoch 70/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0873 - acc: 0.9712 - val_loss: 0.1080 - val_acc: 0.9703
# Epoch 71/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0898 - acc: 0.9705 - val_loss: 0.1116 - val_acc: 0.9708
# Epoch 72/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0868 - acc: 0.9723 - val_loss: 0.0953 - val_acc: 0.9714
# Epoch 73/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0865 - acc: 0.9719 - val_loss: 0.1099 - val_acc: 0.9703
# Epoch 74/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0870 - acc: 0.9720 - val_loss: 0.0991 - val_acc: 0.9716
# Epoch 75/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0866 - acc: 0.9713 - val_loss: 0.1272 - val_acc: 0.9515
# Epoch 76/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0857 - acc: 0.9712 - val_loss: 0.1420 - val_acc: 0.9393
# Epoch 77/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0843 - acc: 0.9728 - val_loss: 0.0987 - val_acc: 0.9730
# Epoch 78/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0853 - acc: 0.9718 - val_loss: 0.1024 - val_acc: 0.9722
# Epoch 79/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0850 - acc: 0.9727 - val_loss: 0.0931 - val_acc: 0.9716
# Epoch 80/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0831 - acc: 0.9727 - val_loss: 0.1032 - val_acc: 0.9716
# Epoch 81/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0847 - acc: 0.9726 - val_loss: 0.0908 - val_acc: 0.9718
# Epoch 82/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0864 - acc: 0.9716 - val_loss: 0.1016 - val_acc: 0.9722
# Epoch 83/200
# 109/109 [==============================] - 1s 14ms/step - loss: 0.0830 - acc: 0.9725 - val_loss: 0.1149 - val_acc: 0.9708
# Epoch 84/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.0848 - acc: 0.9724 - val_loss: 0.1005 - val_acc: 0.9722
# Epoch 85/200
# 109/109 [==============================] - 2s 15ms/step - loss: 0.0848 - acc: 0.9726 - val_loss: 0.0874 - val_acc: 0.9720
# Epoch 86/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0852 - acc: 0.9717 - val_loss: 0.1037 - val_acc: 0.9718
# Epoch 87/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0841 - acc: 0.9722 - val_loss: 0.1116 - val_acc: 0.9714
# Epoch 88/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0829 - acc: 0.9728 - val_loss: 0.1619 - val_acc: 0.9098
# Epoch 89/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0830 - acc: 0.9727 - val_loss: 0.1185 - val_acc: 0.9683
# Epoch 90/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0824 - acc: 0.9733 - val_loss: 0.1063 - val_acc: 0.9710
# Epoch 91/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0828 - acc: 0.9724 - val_loss: 0.1138 - val_acc: 0.9716
# Epoch 92/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0826 - acc: 0.9720 - val_loss: 0.1098 - val_acc: 0.9695
# Epoch 93/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0843 - acc: 0.9729 - val_loss: 0.1243 - val_acc: 0.9640
# Epoch 94/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0821 - acc: 0.9730 - val_loss: 0.1363 - val_acc: 0.9452
# Epoch 95/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0838 - acc: 0.9726 - val_loss: 0.1108 - val_acc: 0.9714
# Epoch 96/200
# 109/109 [==============================] - 1s 14ms/step - loss: 0.0812 - acc: 0.9733 - val_loss: 0.1467 - val_acc: 0.9147
# Epoch 97/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0815 - acc: 0.9726 - val_loss: 0.1141 - val_acc: 0.9695
# Epoch 98/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0809 - acc: 0.9726 - val_loss: 0.1023 - val_acc: 0.9722
# Epoch 99/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0813 - acc: 0.9733 - val_loss: 0.1132 - val_acc: 0.9714
# Epoch 100/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0829 - acc: 0.9737 - val_loss: 0.1085 - val_acc: 0.9703
# Epoch 101/200
# 109/109 [==============================] - 4s 33ms/step - loss: 0.0831 - acc: 0.9735 - val_loss: 0.1000 - val_acc: 0.9714
# Epoch 102/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0809 - acc: 0.9733 - val_loss: 0.0910 - val_acc: 0.9708
# Epoch 103/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0814 - acc: 0.9736 - val_loss: 0.1053 - val_acc: 0.9720
# Epoch 104/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0801 - acc: 0.9739 - val_loss: 0.0966 - val_acc: 0.9726
# Epoch 105/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0821 - acc: 0.9722 - val_loss: 0.0970 - val_acc: 0.9716
# Epoch 106/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0806 - acc: 0.9727 - val_loss: 0.1323 - val_acc: 0.9335
# Epoch 107/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0797 - acc: 0.9733 - val_loss: 0.1136 - val_acc: 0.9706
# Epoch 108/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0799 - acc: 0.9738 - val_loss: 0.1048 - val_acc: 0.9724
# Epoch 109/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0809 - acc: 0.9733 - val_loss: 0.0996 - val_acc: 0.9710
# Epoch 110/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0820 - acc: 0.9722 - val_loss: 0.0999 - val_acc: 0.9728
# Epoch 111/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0807 - acc: 0.9735 - val_loss: 0.1171 - val_acc: 0.9640
# Epoch 112/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0808 - acc: 0.9733 - val_loss: 0.1042 - val_acc: 0.9714
# Epoch 113/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0787 - acc: 0.9738 - val_loss: 0.1223 - val_acc: 0.9452
# Epoch 114/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0797 - acc: 0.9734 - val_loss: 0.1201 - val_acc: 0.9601
# Epoch 115/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0782 - acc: 0.9737 - val_loss: 0.1270 - val_acc: 0.9440

# %%
print_learning_curves(history)

# %% [markdown]
# ### test the results

# %%
preds = baseline_model.predict(X_test_noAgg)
norm_preds = sklearn.preprocessing.normalize(preds)

y_predicted = []
for pred in norm_preds:
  if pred[0] > pred[1]:
    y_predicted.append(0)
  else :
    y_predicted.append(1)
# Out:
# 437/437 [==============================] - 1s 2ms/step

# %%
prec,rec,f1,num = precision_recall_fscore_support(y_test,y_predicted, average=None)
name = "Dense neural network (tx)"
print("Dense neural network (tx)")
print("Precision:%.3f \nRecall:%.3f \nF1 Score:%.3f"%(prec[1],rec[1],f1[1]))
micro_f1 = f1_score(y_test,y_predicted,average='micro')
print("Micro-Average F1 Score:",micro_f1)
# Out:
# Dense neural network (tx)
# Precision:0.959
# Recall:0.756
# F1 Score:0.846
# Micro-Average F1 Score: 0.9739441660701503

# %%
compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)
# Out:
# <ipython-input-110-5fee8f128f02>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)

# %% [markdown]
# ### Training with both tx_features and agg_features

# %%
X = features_known[tx_features+agg_features]
y = features_known['class']
# this is important
y = y.apply(lambda x: 0 if x == 2 else 1 )
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=117,shuffle=True)
#Create a validation set
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.15,random_state=117,shuffle=True)
print("X_train shape",X_train.shape)
print("X_test shape",X_test.shape)
print("X_val shape",X_val.shape)
print("X_test shape",X_test.shape)
print("y_train shape",y_train.shape)
print("y_test shape",y_test.shape)
print("y_val shape",y_val.shape)
# Out:
# X_train shape (27704, 165)
# X_test shape (13970, 165)
# X_val shape (4890, 165)
# X_test shape (13970, 165)
# y_train shape (27704,)
# y_test shape (13970,)
# y_val shape (4890,)

# %%
hidden_units = [130]
learning_rate = 0.001
dropout_rate = 0.4
num_epochs = 200
batch_size = 256

# %%
feature_names = features_known[tx_features+agg_features].columns
num_features = len(feature_names)
num_classes = len(np.unique(y_train))

# %%
baseline_model = create_baseline_model(hidden_units, 2, dropout_rate)
baseline_model.summary()
# Out:
# Model: "baseline"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_features (InputLayer  [(None, 165)]                0         []
#  )
#
#  ffn_block1 (Sequential)     (None, 130)                  22240     ['input_features[0][0]']
#
#  ffn_block2 (Sequential)     (None, 130)                  17550     ['ffn_block1[0][0]']
#
#  skip_connection2 (Add)      (None, 130)                  0         ['ffn_block1[0][0]',
#                                                                      'ffn_block2[0][0]']
#
#  ffn_block3 (Sequential)     (None, 130)                  17550     ['skip_connection2[0][0]']
#
#  skip_connection3 (Add)      (None, 130)                  0         ['skip_connection2[0][0]',
#                                                                      'ffn_block3[0][0]']
#
#  ffn_block4 (Sequential)     (None, 130)                  17550     ['skip_connection3[0][0]']
#
#  skip_connection4 (Add)      (None, 130)                  0         ['skip_connection3[0][0]',
#                                                                      'ffn_block4[0][0]']
#
#  ffn_block5 (Sequential)     (None, 130)                  17550     ['skip_connection4[0][0]']
#
#  skip_connection5 (Add)      (None, 130)                  0         ['skip_connection4[0][0]',
#                                                                      'ffn_block5[0][0]']
#
#  logits (Dense)              (None, 2)                    262       ['skip_connection5[0][0]']
#
# ==================================================================================================
# Total params: 92702 (362.12 KB)
# Trainable params: 91332 (356.77 KB)
# Non-trainable params: 1370 (5.35 KB)
# __________________________________________________________________________________________________

# %%
# Compile the model.
baseline_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)
# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=50, restore_best_weights=True
)
# Fit the model.
history = baseline_model.fit(
    x=X_train,
    y=y_train,
    epochs=num_epochs,
    batch_size=batch_size,
    validation_data = (X_val,y_val),
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/200
# 109/109 [==============================] - 6s 20ms/step - loss: 0.2248 - acc: 0.9234 - val_loss: 0.1888 - val_acc: 0.9256
# Epoch 2/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1637 - acc: 0.9451 - val_loss: 0.1463 - val_acc: 0.9495
# Epoch 3/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1444 - acc: 0.9522 - val_loss: 0.1307 - val_acc: 0.9558
# Epoch 4/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.1360 - acc: 0.9544 - val_loss: 0.1483 - val_acc: 0.9440
# Epoch 5/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.1293 - acc: 0.9567 - val_loss: 0.1243 - val_acc: 0.9573
# Epoch 6/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.1213 - acc: 0.9589 - val_loss: 0.1229 - val_acc: 0.9577
# Epoch 7/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1176 - acc: 0.9597 - val_loss: 0.1453 - val_acc: 0.9468
# Epoch 8/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.1116 - acc: 0.9618 - val_loss: 0.1115 - val_acc: 0.9624
# Epoch 9/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1112 - acc: 0.9631 - val_loss: 0.0967 - val_acc: 0.9685
# Epoch 10/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.1076 - acc: 0.9634 - val_loss: 0.1149 - val_acc: 0.9589
# Epoch 11/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.1032 - acc: 0.9659 - val_loss: 0.0934 - val_acc: 0.9681
# Epoch 12/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0979 - acc: 0.9675 - val_loss: 0.0884 - val_acc: 0.9712
# Epoch 13/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0988 - acc: 0.9664 - val_loss: 0.0946 - val_acc: 0.9671
# Epoch 14/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0951 - acc: 0.9682 - val_loss: 0.0862 - val_acc: 0.9720
# Epoch 15/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0963 - acc: 0.9682 - val_loss: 0.0821 - val_acc: 0.9753
# Epoch 16/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0960 - acc: 0.9672 - val_loss: 0.0853 - val_acc: 0.9748
# Epoch 17/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0920 - acc: 0.9679 - val_loss: 0.0835 - val_acc: 0.9736
# Epoch 18/200
# 109/109 [==============================] - 2s 23ms/step - loss: 0.0907 - acc: 0.9698 - val_loss: 0.0819 - val_acc: 0.9753
# Epoch 19/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.0907 - acc: 0.9694 - val_loss: 0.0793 - val_acc: 0.9763
# Epoch 20/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0916 - acc: 0.9692 - val_loss: 0.0808 - val_acc: 0.9765
# Epoch 21/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0877 - acc: 0.9697 - val_loss: 0.0805 - val_acc: 0.9759
# Epoch 22/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0853 - acc: 0.9718 - val_loss: 0.0758 - val_acc: 0.9777
# Epoch 23/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0843 - acc: 0.9717 - val_loss: 0.0801 - val_acc: 0.9771
# Epoch 24/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0853 - acc: 0.9715 - val_loss: 0.0777 - val_acc: 0.9785
# Epoch 25/200
# 109/109 [==============================] - 3s 27ms/step - loss: 0.0822 - acc: 0.9716 - val_loss: 0.0754 - val_acc: 0.9773
# Epoch 26/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0814 - acc: 0.9734 - val_loss: 0.0749 - val_acc: 0.9789
# Epoch 27/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0818 - acc: 0.9721 - val_loss: 0.0848 - val_acc: 0.9759
# Epoch 28/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0814 - acc: 0.9724 - val_loss: 0.0805 - val_acc: 0.9771
# Epoch 29/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0798 - acc: 0.9727 - val_loss: 0.0773 - val_acc: 0.9785
# Epoch 30/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0798 - acc: 0.9733 - val_loss: 0.0770 - val_acc: 0.9791
# Epoch 31/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0802 - acc: 0.9729 - val_loss: 0.0776 - val_acc: 0.9791
# Epoch 32/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0771 - acc: 0.9743 - val_loss: 0.0801 - val_acc: 0.9777
# Epoch 33/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0763 - acc: 0.9744 - val_loss: 0.0798 - val_acc: 0.9767
# Epoch 34/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0769 - acc: 0.9733 - val_loss: 0.0801 - val_acc: 0.9773
# Epoch 35/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0770 - acc: 0.9747 - val_loss: 0.0753 - val_acc: 0.9785
# Epoch 36/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0779 - acc: 0.9731 - val_loss: 0.0746 - val_acc: 0.9791
# Epoch 37/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0745 - acc: 0.9753 - val_loss: 0.0782 - val_acc: 0.9787
# Epoch 38/200
# 109/109 [==============================] - 2s 23ms/step - loss: 0.0719 - acc: 0.9752 - val_loss: 0.0761 - val_acc: 0.9798
# Epoch 39/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.0734 - acc: 0.9750 - val_loss: 0.0741 - val_acc: 0.9789
# Epoch 40/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0786 - acc: 0.9738 - val_loss: 0.0701 - val_acc: 0.9802
# Epoch 41/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0742 - acc: 0.9735 - val_loss: 0.0803 - val_acc: 0.9787
# Epoch 42/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0739 - acc: 0.9749 - val_loss: 0.0733 - val_acc: 0.9787
# Epoch 43/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0711 - acc: 0.9753 - val_loss: 0.0705 - val_acc: 0.9796
# Epoch 44/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0732 - acc: 0.9750 - val_loss: 0.0770 - val_acc: 0.9773
# Epoch 45/200
# 109/109 [==============================] - 3s 27ms/step - loss: 0.0699 - acc: 0.9762 - val_loss: 0.0697 - val_acc: 0.9804
# Epoch 46/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0709 - acc: 0.9764 - val_loss: 0.0827 - val_acc: 0.9779
# Epoch 47/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0675 - acc: 0.9774 - val_loss: 0.0748 - val_acc: 0.9796
# Epoch 48/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0728 - acc: 0.9752 - val_loss: 0.0714 - val_acc: 0.9785
# Epoch 49/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0684 - acc: 0.9756 - val_loss: 0.0707 - val_acc: 0.9789
# Epoch 50/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0671 - acc: 0.9771 - val_loss: 0.0716 - val_acc: 0.9789
# Epoch 51/200
# 109/109 [==============================] - 2s 22ms/step - loss: 0.0685 - acc: 0.9756 - val_loss: 0.0716 - val_acc: 0.9802
# Epoch 52/200
# 109/109 [==============================] - 2s 23ms/step - loss: 0.0677 - acc: 0.9770 - val_loss: 0.0742 - val_acc: 0.9798
# Epoch 53/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0663 - acc: 0.9765 - val_loss: 0.0782 - val_acc: 0.9763
# Epoch 54/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0683 - acc: 0.9761 - val_loss: 0.0697 - val_acc: 0.9789
# Epoch 55/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0650 - acc: 0.9775 - val_loss: 0.0760 - val_acc: 0.9787
# Epoch 56/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0673 - acc: 0.9769 - val_loss: 0.0755 - val_acc: 0.9787
# Epoch 57/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0651 - acc: 0.9771 - val_loss: 0.0695 - val_acc: 0.9796
# Epoch 58/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0674 - acc: 0.9768 - val_loss: 0.0680 - val_acc: 0.9800
# Epoch 59/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0658 - acc: 0.9772 - val_loss: 0.0686 - val_acc: 0.9785
# Epoch 60/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0636 - acc: 0.9786 - val_loss: 0.0774 - val_acc: 0.9775
# Epoch 61/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0642 - acc: 0.9778 - val_loss: 0.0651 - val_acc: 0.9810
# Epoch 62/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0645 - acc: 0.9773 - val_loss: 0.0774 - val_acc: 0.9767
# Epoch 63/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0647 - acc: 0.9787 - val_loss: 0.0735 - val_acc: 0.9781
# Epoch 64/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0618 - acc: 0.9788 - val_loss: 0.0704 - val_acc: 0.9798
# Epoch 65/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.0626 - acc: 0.9784 - val_loss: 0.0750 - val_acc: 0.9779
# Epoch 66/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0631 - acc: 0.9781 - val_loss: 0.0736 - val_acc: 0.9787
# Epoch 67/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0626 - acc: 0.9786 - val_loss: 0.0714 - val_acc: 0.9798
# Epoch 68/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0625 - acc: 0.9781 - val_loss: 0.0686 - val_acc: 0.9802
# Epoch 69/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0619 - acc: 0.9782 - val_loss: 0.0708 - val_acc: 0.9800
# Epoch 70/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0632 - acc: 0.9782 - val_loss: 0.0674 - val_acc: 0.9800
# Epoch 71/200
# 109/109 [==============================] - 2s 22ms/step - loss: 0.0603 - acc: 0.9800 - val_loss: 0.0689 - val_acc: 0.9787
# Epoch 72/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.0616 - acc: 0.9779 - val_loss: 0.0666 - val_acc: 0.9793
# Epoch 73/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0599 - acc: 0.9793 - val_loss: 0.0703 - val_acc: 0.9791
# Epoch 74/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0618 - acc: 0.9788 - val_loss: 0.0651 - val_acc: 0.9804
# Epoch 75/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0596 - acc: 0.9788 - val_loss: 0.0724 - val_acc: 0.9773
# Epoch 76/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0622 - acc: 0.9782 - val_loss: 0.0761 - val_acc: 0.9771
# Epoch 77/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0596 - acc: 0.9799 - val_loss: 0.0720 - val_acc: 0.9787
# Epoch 78/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.0602 - acc: 0.9793 - val_loss: 0.0750 - val_acc: 0.9787
# Epoch 79/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0596 - acc: 0.9794 - val_loss: 0.0705 - val_acc: 0.9783
# Epoch 80/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0612 - acc: 0.9791 - val_loss: 0.0711 - val_acc: 0.9798
# Epoch 81/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0608 - acc: 0.9783 - val_loss: 0.0662 - val_acc: 0.9816
# Epoch 82/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0597 - acc: 0.9799 - val_loss: 0.0648 - val_acc: 0.9802
# Epoch 83/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0615 - acc: 0.9789 - val_loss: 0.0671 - val_acc: 0.9802
# Epoch 84/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0581 - acc: 0.9800 - val_loss: 0.0664 - val_acc: 0.9789
# Epoch 85/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.0562 - acc: 0.9806 - val_loss: 0.0669 - val_acc: 0.9816
# Epoch 86/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0577 - acc: 0.9799 - val_loss: 0.0665 - val_acc: 0.9802
# Epoch 87/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0561 - acc: 0.9804 - val_loss: 0.0664 - val_acc: 0.9810
# Epoch 88/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0562 - acc: 0.9806 - val_loss: 0.0686 - val_acc: 0.9800
# Epoch 89/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0563 - acc: 0.9806 - val_loss: 0.0664 - val_acc: 0.9806
# Epoch 90/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0566 - acc: 0.9801 - val_loss: 0.0685 - val_acc: 0.9787
# Epoch 91/200
# 109/109 [==============================] - 2s 23ms/step - loss: 0.0573 - acc: 0.9796 - val_loss: 0.0681 - val_acc: 0.9800
# Epoch 92/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.0537 - acc: 0.9814 - val_loss: 0.0660 - val_acc: 0.9802
# Epoch 93/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0548 - acc: 0.9802 - val_loss: 0.0689 - val_acc: 0.9798
# Epoch 94/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0566 - acc: 0.9802 - val_loss: 0.0721 - val_acc: 0.9793
# Epoch 95/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0549 - acc: 0.9816 - val_loss: 0.0697 - val_acc: 0.9802
# Epoch 96/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0577 - acc: 0.9795 - val_loss: 0.0683 - val_acc: 0.9798
# Epoch 97/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0571 - acc: 0.9802 - val_loss: 0.0675 - val_acc: 0.9802
# Epoch 98/200
# 109/109 [==============================] - 3s 27ms/step - loss: 0.0554 - acc: 0.9805 - val_loss: 0.0705 - val_acc: 0.9806
# Epoch 99/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0538 - acc: 0.9809 - val_loss: 0.0661 - val_acc: 0.9814
# Epoch 100/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0554 - acc: 0.9799 - val_loss: 0.0656 - val_acc: 0.9802
# Epoch 101/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0523 - acc: 0.9812 - val_loss: 0.0671 - val_acc: 0.9804
# Epoch 102/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0543 - acc: 0.9814 - val_loss: 0.0661 - val_acc: 0.9796
# Epoch 103/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0553 - acc: 0.9799 - val_loss: 0.0747 - val_acc: 0.9787
# Epoch 104/200
# 109/109 [==============================] - 2s 22ms/step - loss: 0.0527 - acc: 0.9815 - val_loss: 0.0677 - val_acc: 0.9800
# Epoch 105/200
# 109/109 [==============================] - 2s 22ms/step - loss: 0.0551 - acc: 0.9805 - val_loss: 0.0669 - val_acc: 0.9812
# Epoch 106/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0566 - acc: 0.9805 - val_loss: 0.0685 - val_acc: 0.9793
# Epoch 107/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0527 - acc: 0.9819 - val_loss: 0.0657 - val_acc: 0.9808
# Epoch 108/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0537 - acc: 0.9812 - val_loss: 0.0695 - val_acc: 0.9793
# Epoch 109/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0541 - acc: 0.9812 - val_loss: 0.0706 - val_acc: 0.9789
# Epoch 110/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0521 - acc: 0.9809 - val_loss: 0.0621 - val_acc: 0.9830
# Epoch 111/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.0537 - acc: 0.9806 - val_loss: 0.0626 - val_acc: 0.9812
# Epoch 112/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0546 - acc: 0.9803 - val_loss: 0.0637 - val_acc: 0.9810
# Epoch 113/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0526 - acc: 0.9805 - val_loss: 0.0719 - val_acc: 0.9793
# Epoch 114/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0532 - acc: 0.9812 - val_loss: 0.0683 - val_acc: 0.9781
# Epoch 115/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0547 - acc: 0.9795 - val_loss: 0.0658 - val_acc: 0.9802
# Epoch 116/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0512 - acc: 0.9822 - val_loss: 0.0672 - val_acc: 0.9812
# Epoch 117/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0504 - acc: 0.9814 - val_loss: 0.0652 - val_acc: 0.9808
# Epoch 118/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0522 - acc: 0.9817 - val_loss: 0.0736 - val_acc: 0.9793
# Epoch 119/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0529 - acc: 0.9817 - val_loss: 0.0640 - val_acc: 0.9820
# Epoch 120/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0520 - acc: 0.9821 - val_loss: 0.0666 - val_acc: 0.9814
# Epoch 121/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0516 - acc: 0.9819 - val_loss: 0.0698 - val_acc: 0.9798
# Epoch 122/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0508 - acc: 0.9812 - val_loss: 0.0624 - val_acc: 0.9834
# Epoch 123/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0503 - acc: 0.9819 - val_loss: 0.0707 - val_acc: 0.9800
# Epoch 124/200
# 109/109 [==============================] - 2s 22ms/step - loss: 0.0476 - acc: 0.9834 - val_loss: 0.0704 - val_acc: 0.9802
# Epoch 125/200
# 109/109 [==============================] - 2s 23ms/step - loss: 0.0524 - acc: 0.9810 - val_loss: 0.0683 - val_acc: 0.9791
# Epoch 126/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0507 - acc: 0.9826 - val_loss: 0.0651 - val_acc: 0.9806
# Epoch 127/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0488 - acc: 0.9826 - val_loss: 0.0644 - val_acc: 0.9802
# Epoch 128/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0510 - acc: 0.9816 - val_loss: 0.0696 - val_acc: 0.9783
# Epoch 129/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0502 - acc: 0.9820 - val_loss: 0.0767 - val_acc: 0.9769
# Epoch 130/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0500 - acc: 0.9820 - val_loss: 0.0754 - val_acc: 0.9787
# Epoch 131/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.0510 - acc: 0.9822 - val_loss: 0.0680 - val_acc: 0.9798
# Epoch 132/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0496 - acc: 0.9829 - val_loss: 0.0696 - val_acc: 0.9806
# Epoch 133/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0507 - acc: 0.9813 - val_loss: 0.0655 - val_acc: 0.9804
# Epoch 134/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0489 - acc: 0.9823 - val_loss: 0.0709 - val_acc: 0.9791
# Epoch 135/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0495 - acc: 0.9821 - val_loss: 0.0670 - val_acc: 0.9800
# Epoch 136/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0501 - acc: 0.9818 - val_loss: 0.0685 - val_acc: 0.9796
# Epoch 137/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.0510 - acc: 0.9825 - val_loss: 0.0710 - val_acc: 0.9791
# Epoch 138/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0497 - acc: 0.9826 - val_loss: 0.0654 - val_acc: 0.9810
# Epoch 139/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0490 - acc: 0.9825 - val_loss: 0.0710 - val_acc: 0.9802
# Epoch 140/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0510 - acc: 0.9824 - val_loss: 0.0686 - val_acc: 0.9800
# Epoch 141/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0505 - acc: 0.9817 - val_loss: 0.0730 - val_acc: 0.9798
# Epoch 142/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0494 - acc: 0.9817 - val_loss: 0.0746 - val_acc: 0.9796
# Epoch 143/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0482 - acc: 0.9830 - val_loss: 0.0711 - val_acc: 0.9798
# Epoch 144/200
# 109/109 [==============================] - 3s 24ms/step - loss: 0.0492 - acc: 0.9818 - val_loss: 0.0741 - val_acc: 0.9779
# Epoch 145/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.0506 - acc: 0.9818 - val_loss: 0.0649 - val_acc: 0.9810
# Epoch 146/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0494 - acc: 0.9822 - val_loss: 0.0674 - val_acc: 0.9802
# Epoch 147/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0497 - acc: 0.9820 - val_loss: 0.0653 - val_acc: 0.9806
# Epoch 148/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0504 - acc: 0.9821 - val_loss: 0.0663 - val_acc: 0.9806
# Epoch 149/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0461 - acc: 0.9836 - val_loss: 0.0653 - val_acc: 0.9808
# Epoch 150/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0475 - acc: 0.9824 - val_loss: 0.0708 - val_acc: 0.9808
# Epoch 151/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.0496 - acc: 0.9820 - val_loss: 0.0621 - val_acc: 0.9810
# Epoch 152/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0511 - acc: 0.9821 - val_loss: 0.0635 - val_acc: 0.9816
# Epoch 153/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0480 - acc: 0.9826 - val_loss: 0.0614 - val_acc: 0.9824
# Epoch 154/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0452 - acc: 0.9836 - val_loss: 0.0652 - val_acc: 0.9814
# Epoch 155/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0459 - acc: 0.9844 - val_loss: 0.0645 - val_acc: 0.9812
# Epoch 156/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0511 - acc: 0.9812 - val_loss: 0.0622 - val_acc: 0.9814
# Epoch 157/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.0460 - acc: 0.9836 - val_loss: 0.0673 - val_acc: 0.9810
# Epoch 158/200
# 109/109 [==============================] - 2s 23ms/step - loss: 0.0457 - acc: 0.9834 - val_loss: 0.0733 - val_acc: 0.9798
# Epoch 159/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0471 - acc: 0.9832 - val_loss: 0.0721 - val_acc: 0.9804
# Epoch 160/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0476 - acc: 0.9817 - val_loss: 0.0684 - val_acc: 0.9804
# Epoch 161/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0471 - acc: 0.9832 - val_loss: 0.0651 - val_acc: 0.9806
# Epoch 162/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0485 - acc: 0.9819 - val_loss: 0.0634 - val_acc: 0.9816
# Epoch 163/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0482 - acc: 0.9834 - val_loss: 0.0658 - val_acc: 0.9822
# Epoch 164/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0493 - acc: 0.9816 - val_loss: 0.0700 - val_acc: 0.9806
# Epoch 165/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.0462 - acc: 0.9830 - val_loss: 0.0656 - val_acc: 0.9816
# Epoch 166/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0458 - acc: 0.9835 - val_loss: 0.0663 - val_acc: 0.9814
# Epoch 167/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0456 - acc: 0.9826 - val_loss: 0.0691 - val_acc: 0.9810
# Epoch 168/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0474 - acc: 0.9822 - val_loss: 0.0635 - val_acc: 0.9816
# Epoch 169/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0460 - acc: 0.9838 - val_loss: 0.0705 - val_acc: 0.9820
# Epoch 170/200
# 109/109 [==============================] - 2s 22ms/step - loss: 0.0475 - acc: 0.9826 - val_loss: 0.0668 - val_acc: 0.9820
# Epoch 171/200
# 109/109 [==============================] - 3s 23ms/step - loss: 0.0453 - acc: 0.9833 - val_loss: 0.0692 - val_acc: 0.9808
# Epoch 172/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0473 - acc: 0.9831 - val_loss: 0.0713 - val_acc: 0.9796
# Epoch 173/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0473 - acc: 0.9826 - val_loss: 0.0665 - val_acc: 0.9808
# Epoch 174/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0466 - acc: 0.9828 - val_loss: 0.0713 - val_acc: 0.9798
# Epoch 175/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0449 - acc: 0.9839 - val_loss: 0.0665 - val_acc: 0.9810
# Epoch 176/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0439 - acc: 0.9846 - val_loss: 0.0710 - val_acc: 0.9802
# Epoch 177/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.0464 - acc: 0.9838 - val_loss: 0.0669 - val_acc: 0.9802
# Epoch 178/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0470 - acc: 0.9838 - val_loss: 0.0664 - val_acc: 0.9804
# Epoch 179/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0450 - acc: 0.9838 - val_loss: 0.0761 - val_acc: 0.9787
# Epoch 180/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0464 - acc: 0.9836 - val_loss: 0.0674 - val_acc: 0.9804
# Epoch 181/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0447 - acc: 0.9840 - val_loss: 0.0678 - val_acc: 0.9808
# Epoch 182/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0435 - acc: 0.9839 - val_loss: 0.0671 - val_acc: 0.9810
# Epoch 183/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.0461 - acc: 0.9829 - val_loss: 0.0625 - val_acc: 0.9824
# Epoch 184/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.0425 - acc: 0.9852 - val_loss: 0.0698 - val_acc: 0.9800
# Epoch 185/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0450 - acc: 0.9833 - val_loss: 0.0680 - val_acc: 0.9804
# Epoch 186/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0462 - acc: 0.9832 - val_loss: 0.0666 - val_acc: 0.9812
# Epoch 187/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0462 - acc: 0.9833 - val_loss: 0.0700 - val_acc: 0.9802
# Epoch 188/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0453 - acc: 0.9839 - val_loss: 0.0702 - val_acc: 0.9800
# Epoch 189/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0467 - acc: 0.9831 - val_loss: 0.0739 - val_acc: 0.9800
# Epoch 190/200
# 109/109 [==============================] - 3s 24ms/step - loss: 0.0468 - acc: 0.9833 - val_loss: 0.0737 - val_acc: 0.9791
# Epoch 191/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.0452 - acc: 0.9834 - val_loss: 0.0646 - val_acc: 0.9808
# Epoch 192/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0437 - acc: 0.9840 - val_loss: 0.0782 - val_acc: 0.9785
# Epoch 193/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0469 - acc: 0.9831 - val_loss: 0.0688 - val_acc: 0.9793
# Epoch 194/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0448 - acc: 0.9843 - val_loss: 0.0687 - val_acc: 0.9806
# Epoch 195/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0436 - acc: 0.9848 - val_loss: 0.0697 - val_acc: 0.9796
# Epoch 196/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0427 - acc: 0.9846 - val_loss: 0.0712 - val_acc: 0.9798
# Epoch 197/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.0484 - acc: 0.9822 - val_loss: 0.0691 - val_acc: 0.9791
# Epoch 198/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0444 - acc: 0.9833 - val_loss: 0.0647 - val_acc: 0.9798
# Epoch 199/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0451 - acc: 0.9832 - val_loss: 0.0672 - val_acc: 0.9781
# Epoch 200/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0439 - acc: 0.9840 - val_loss: 0.0700 - val_acc: 0.9781

# %%
print_learning_curves(history)

# %% [markdown]
# ### test the results

# %%
preds = baseline_model.predict(X_test)
norm_preds = sklearn.preprocessing.normalize(preds)

y_predicted = []
for pred in norm_preds:
  if pred[0] > pred[1]:
    y_predicted.append(0)
  else :
    y_predicted.append(1)
# Out:
# 437/437 [==============================] - 1s 2ms/step

# %%
prec,rec,f1,num = precision_recall_fscore_support(y_test,y_predicted, average=None)
name = "Dense neural network (tx + agg)"
print("Dense neural network (tx + agg)")
print("Precision:%.3f \nRecall:%.3f \nF1 Score:%.3f"%(prec[1],rec[1],f1[1]))
micro_f1 = f1_score(y_test,y_predicted,average='micro')
print("Micro-Average F1 Score:",micro_f1)
# Out:
# Dense neural network (tx + agg)
# Precision:0.947
# Recall:0.845
# F1 Score:0.893
# Micro-Average F1 Score: 0.9809591982820329

# %%
compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)
# Out:
# <ipython-input-119-5fee8f128f02>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)

# %% [markdown]
# ### classify the unknown transactions with the Neural network

# %%
X = features_unknown[tx_features+agg_features]
preds = baseline_model.predict(X)

norm_preds = sklearn.preprocessing.normalize(preds)

y_predicted = []
for pred in norm_preds:
  if pred[0] > pred[1]:
    y_predicted.append(0)
  else :
    y_predicted.append(1)

preds = pd.DataFrame(y_predicted,columns=['class'])
features_unknown = features_unknown[['txId']+tx_features+agg_features].join(preds)
features_unknown['class'] = features_unknown['class'].apply(lambda x: 2 if x==0 else 1)
features_classified = features_known.append(features_unknown)
# Out:
# 4913/4913 [==============================] - 10s 2ms/step
# <ipython-input-120-ccfb790f4210>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_classified = features_known.append(features_unknown)

# %% [markdown]
# Once again exploring the distribution of licit/illicit transaction in the dataset and the results are very comparable to the ones obtained with Random Forest and Logistic Regression

# %%
features_unknown['class'].hist()
features_unknown['class'].value_counts(normalize=True) * 100
# Out:
# 2    72.107121
# 1    27.892879
# Name: class, dtype: float64

# %%
X = features_known[tx_features+agg_features]
y = features_known['class']
# this is important
y = y.apply(lambda x: 0 if x == 2 else 1 )
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=117,shuffle=True)
#Create a validation set
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.15,random_state=117,shuffle=True)
print("X_train shape",X_train.shape)
print("X_test shape",X_test.shape)
print("X_val shape",X_val.shape)
print("X_test shape",X_test.shape)
print("y_train shape",y_train.shape)
print("y_test shape",y_test.shape)
print("y_val shape",y_val.shape)
# Out:
# X_train shape (27704, 165)
# X_test shape (13970, 165)
# X_val shape (4890, 165)
# X_test shape (13970, 165)
# y_train shape (27704,)
# y_test shape (13970,)
# y_val shape (4890,)

# %%
features_known['class'].hist()
features_known['class'].value_counts(normalize=True) * 100
# Out:
# 2    90.239241
# 1     9.760759
# Name: class, dtype: float64

# %% [markdown]
# ## Compare the obtained results

# %% [markdown]
# The following table contains all the results obtained with the classifiers above. Training on this kind of dataset, driven by time rather than class distribution, can produce different results in different training session.

# %%
compare.head(10)
# Out:
#                                  model  Precision  Recall  F1 Score  \
# 0        Random Forest Classifier (tx)      0.981   0.854     0.913
# 1  Random Forest Classifier (tx + agg)      0.994   0.888     0.938
# 2             Logistic Regression (tx)      0.910   0.725     0.807
# 3       Logistic Regression (tx + agg)      0.848   0.791     0.819
# 4            Dense neural network (tx)      0.959   0.756     0.846
# 5      Dense neural network (tx + agg)      0.947   0.845     0.893
#
#    M.A F1 Score
# 0         0.985
# 1         0.989
# 2         0.967
# 3         0.967
# 4         0.974
# 5         0.981

# %%
labels = compare['model'].to_numpy()

# %%
precision = compare['Precision'].to_numpy()
recall = compare['Recall'].to_numpy()
f1 = compare['F1 Score'].to_numpy()
maf1 = compare['M.A F1 Score'].to_numpy()

x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars
fig, ax = plt.subplots(figsize=(20, 7))
prec_rects = ax.bar(x - width/2, precision, width, label='Precision',color='#83f27b')
rec_rects = ax.bar(x + width/2, recall, width, label='Recall',color='#f27b83')
f1_rects = ax.bar(x - (3/2)*width, f1, width, label='F1 Score',color='#f2b37b')
MAf1_rects = ax.bar(x + (3/2)*width, maf1, width, label='M.A. F1 Score',color='#7b8bf2')

ax.set_ylabel('value 0-1')
ax.set_title('Final metrics by classifier')
ax.set_xticks(np.arange(0,len(labels),1))
ax.set_yticks(np.arange(0,1,0.05))
ax.set_xticklabels(labels=labels)
ax.legend()

plt.grid(True)
fig.tight_layout()
plt.show()

# %% [markdown]
# We can see in the  following table that the results obtained are in-line with the paper's result.

# %%
precision = compare['Precision'].to_numpy()
recall = compare['Recall'].to_numpy()
f1 = compare['F1 Score'].to_numpy()
maf1 = compare['M.A F1 Score'].to_numpy()

x = np.arange(len(labels))  # the label locations
width = 0.55  # the width of the bars
fig, ax = plt.subplots(figsize=(6, 10))
f1_rects = ax.bar(x, f1, width, label='F1 Score',color='#f2b37b')
MAf1_rects = ax.bar(x , maf1, width, label='M.A. F1 Score',color='#7b8bf2',bottom=f1)
prec_rects = ax.bar(x, precision, width, label='Precision',color='#83f27b',bottom=maf1 + f1)
rec_rects = ax.bar(x, recall, width, label='Recall',color='#f27b83',bottom=maf1 + f1 + precision)

ax.set_ylabel('value 0-1')
ax.set_title('Final metrics by classifier')
ax.set_xticks(np.arange(0,len(labels),1))
ax.set_yticks(np.arange(0,4,0.1))
ax.set_xticklabels(labels=labels)
ax.legend()

plt.xticks(rotation=90)
plt.grid(True)
fig.tight_layout()
plt.show()

# %% [markdown]
# Save the results for later use

# %%
compare.to_csv("/content/elliptic_bitcoin_dataset_cont/1_result_elliptic.csv")
