# %% [markdown]
# <a href="https://colab.research.google.com/github/Lizzie1234567/GCN_detect_bitcoin_money_laundering/blob/main/1_aml_noTimeStep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Anti Money Laundering in Elliptic Blockchain dataset

# %% [markdown]
# Project outline
#
# *   Implement the paper
# *   Change architectures from Torch to Keras
# *   Develop the tracking algorithm
# *   Develop a GAT model and compare it to the GCN
# *   Compare all the results

# %% [markdown]
# ## Prepare and inspect data

# %% [markdown]
# ### imports

# %%
import os
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import sklearn

# %% [markdown]
# ### data retrival

# %%
# Prepare a dataFrame for results, used in the last part for a general comparison
compare = pd.DataFrame(columns=['model','Precision','Recall', 'F1 Score','M.A F1 Score'])

# %%
# zip_file = keras.utils.get_file(
#     fname="elliptic.zip",
#     origin="https://storage.googleapis.com/kaggle-data-sets/284040/584717/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20211206%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20211206T132009Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...",
#     extract=True,
# )
# print(zip_file)

# %%
# cd /root/.keras/datasets/elliptic_bitcoin_dataset

# %%
# os.environ['KAGGLE_USERNAME'] = "lizzylin067@gmail.com" # username from the json file
# os.environ['KAGGLE_KEY'] = "Kaggle067!" # key from the json file


# !kaggle datasets download -d ellipticco/elliptic-data-set
# !unzip elliptic-data-set.zip
# !mkdir elliptic_bitcoin_dataset_cont

import os

os.environ['KAGGLE_USERNAME'] = "henry067"
os.environ['KAGGLE_KEY'] = "0d6098f677227f95b88639d89e049217"

# !kaggle datasets download -d ellipticco/elliptic-data-set

# Unzip the file if it exists
if os.path.exists("elliptic-data-set.zip"):
    # !unzip elliptic-data-set.zip

# Create the directory if it doesn't exist
if not os.path.exists("elliptic_bitcoin_dataset_cont"):
    os.makedirs("elliptic_bitcoin_dataset_cont")
# Out:
# Downloading elliptic-data-set.zip to /content
#  97% 142M/146M [00:05<00:00, 28.0MB/s]
# 100% 146M/146M [00:05<00:00, 27.8MB/s]
# Archive:  elliptic-data-set.zip
#   inflating: elliptic_bitcoin_dataset/elliptic_txs_classes.csv
#   inflating: elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv
#   inflating: elliptic_bitcoin_dataset/elliptic_txs_features.csv

# %%
edges = pd.read_csv("elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv")
features = pd.read_csv("elliptic_bitcoin_dataset/elliptic_txs_features.csv",header=None)
classes = pd.read_csv("elliptic_bitcoin_dataset/elliptic_txs_classes.csv")

# %%
print(edges.shape)
print(features.shape)
print(classes.shape)
# Out:
# (234355, 2)
# (203769, 167)
# (203769, 2)

# %% [markdown]
# ### data preparation

# %%
#name all the features
tx_features = ["tx_feat_"+str(i) for i in range(2,95)]
agg_features = ["agg_feat_"+str(i) for i in range(1,73)]
features.columns = ["txId","time_step"] + tx_features + agg_features

#merge features and classes
features = pd.merge(features,classes,left_on="txId",right_on="txId",how='left')
features['class'] = features['class'].apply(lambda x: 0 if x == "unknown" else x)
features['class'] = features['class'].apply(lambda x: 1 if x == '1' else x)
features['class'] = features['class'].apply(lambda x: 2 if x == '2' else x)

# %%
features['class'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### swap the index
# for easier of use, we change the TxId identifier for the integer index. This simply many of the following considerations

# %%
class_values = sorted(features["class"].unique())
#we create a new index by sorting the tx_ids and assign to it a number
features_idx = {name: idx for idx, name in enumerate(sorted(features["txId"].unique()))}

# we then apply this new ids to all te data frames
# this helps a lot in computing the adjency matrix, having the ids as the index.
features["txId"] = features["txId"].apply(lambda name: features_idx[name])
edges["txId1"] = edges["txId1"].apply(lambda name: features_idx[name])
edges["txId2"] = edges["txId2"].apply(lambda name: features_idx[name])

# %% [markdown]
# ## The tracker
# The tracker is a function thats able to build the connected graph of a given transaction, displaying the graph, and compare it to the classified one.
# It can be used to look for particular clusters, for example the biggest connected graph, or it can be used to track a specific transaction.

# %% [markdown]
# ### the tracking function

# %%
# The tracker function recursively scans the network looking for the connected group to a given transaction.
# the deep levels represent the amount of recursive iterations it computes

def tracker(deep_levels, seed, edges):
  tmp = {seed}
  keep = set()
  counter = 0

  for i in range(deep_levels):
    for j in tmp:
      counter = counter + 1
      one = edges[edges['txId1'] == j]
      #add first
      tmp = set.union(tmp,set(one['txId2'].iloc[:]))

      two = edges[edges['txId2'] == j]
      #add second
      tmp = set.union(tmp,set(two['txId1'].iloc[:]))
      # check if connected group is empty
      if(len(one) == 0 & len(two) == 0):
          edgeList = edges[edges['txId1'].isin(keep)]
          return keep,edgeList,counter,True

      keep.add(j)
      tmp.remove(j)

  edgeList = edges[edges['txId1'].isin(keep)]
  return keep,edgeList,counter,False

# %%
def get_random_illicit(features):
  # get a random illicit transaction
  randomIllicit = features[features["class"] == 1].sample(1)["txId"]
  seed = randomIllicit.to_numpy()[0]
  # define the final DF containg the cluster
  return seed

# %%
def get_random_licit(features):
  # get a random illicit transaction
  randomLicit = features[features["class"] == 2].sample(1)["txId"]
  seed = randomLicit.to_numpy()[0]
  # define the final DF containg the cluster
  return seed

# %% [markdown]
# ### Plot an example graph

# %%
deep_levels = 20
keep = {}
tries = 0
minimum_nodes = 50

while(len(keep) < minimum_nodes):
  seed = get_random_illicit(features)
  keep,edgeList,counter,complete = tracker(deep_levels,seed,edges)
  tries = tries + 1

print("is the graph complete: ",complete)
print("iterations-> ",counter)
print("transactions found->",len(keep))
print("seed : ",seed)
print("seed tried:", tries)
print("transactions : \n")

print(edgeList)
# Out:
# is the graph complete:  True
# iterations->  68
# transactions found-> 66
# seed :  181740
# seed tried: 84
# transactions :
#
#         txId1   txId2
# 78616  182455  184651
# 78640  182709  184651
# 78672    7050  184931
# 78805  183816  184989
# 78822  183255  184651
# ...       ...     ...
# 83309  181654  181653
# 83310  181740  184651
# 83319  182884  183901
# 83350  183044   35539
# 83384  181654  184651
#
# [81 rows x 2 columns]

# %%
plt.figure(figsize=(10, 10))
import networkx as nx
transaction_graph = nx.from_pandas_edgelist(edgeList,source='txId1', target='txId2')
#transaction_type = features[features["txId"].isin(list(transaction_graph.nodes))]["class"]
transaction_type = features[features["txId"].isin(list(transaction_graph.nodes))]["class"]
transaction_type = transaction_type.apply(lambda x: 'gray' if x == 0 else x)
transaction_type = transaction_type.apply(lambda x: 'red' if x == 1 else x)
transaction_type = transaction_type.apply(lambda x: 'green' if x == 2 else x)
nx.draw_spring(transaction_graph,node_size=50, node_color=list(transaction_type),width=1)

# %% [markdown]
# Example of the connected group starting from 15292

# %% [markdown]
# ## Classification

# %% [markdown]
# ### select only the known part

# %%
# helper function
def check(name):
  if(name in unique):
    return name
  else :
    return -1

# %%
# get the features of the known transactions
features_known = features[features['class'] != 0 ]
features_unknown = features[features['class'] == 0 ]
edges_known = edges.copy()

# remove from the edges DF all the entries that mentions the unknown transactions
unique = features_known['txId'].unique()
edges_known["txId1"] = edges["txId1"].apply(lambda name: check(name))
edges_known["txId2"] = edges["txId2"].apply(lambda name: check(name))

edges_known = edges_known[edges_known["txId1"] != -1 ]
edges_known = edges_known[edges_known["txId2"] != -1 ]

print(edges_known.shape)
print(features.shape)
print(features_known.shape)
print(features_unknown.shape)
# Out:
# (36624, 2)
# (203769, 168)
# (46564, 168)
# (157205, 168)

# %% [markdown]
# ### split the data in train and test

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV

# %%
#Split the data, with the aggregated features

X = features_known[tx_features+agg_features]
y = features_known['class']
# this is important
y = y.apply(lambda x: 0 if x == 2 else 1 )
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=117,shuffle=True)
print("X_train shape",X_train.shape)
print("X_test shape",X_test.shape)
print("y_train shape",y_train.shape)
print("y_test shape",y_test.shape)
# Out:
# X_train shape (32594, 165)
# X_test shape (13970, 165)
# y_train shape (32594,)
# y_test shape (13970,)

# %%
#Split the data, without the aggregated features

X_noAgg = features_known[tx_features]
y_noAgg = features_known['class']
# this is important
y_noAgg = y_noAgg.apply(lambda x: 0 if x == 2 else 1 )
X_train_noAgg, X_test_noAgg, y_train_noAgg, y_test_noAgg = train_test_split(X_noAgg,y_noAgg,test_size=0.3,random_state=117,shuffle=True)
print("X_train shape",X_train_noAgg.shape)
print("X_test shape",X_test_noAgg.shape)
print("y_train shape",y_train_noAgg.shape)
print("y_test shape",y_test_noAgg.shape)
# Out:
# X_train shape (32594, 93)
# X_test shape (13970, 93)
# y_train shape (32594,)
# y_test shape (13970,)

# %% [markdown]
# ### Classification with Random Forest and Logistic Regression

# %% [markdown]
# The classification is done for both classifiers with and without aggregated features

# %%
clf = RandomForestClassifier(n_estimators=50, max_depth=100,random_state=15).fit(X_train_noAgg,y_train_noAgg)
preds = clf.predict(X_test_noAgg)
prec,rec,f1,num = precision_recall_fscore_support(y_test_noAgg,preds, average=None)
name = "Random Forest Classifier (tx)"
print(name)
print("Precision:%.3f \nRecall:%.3f \nF1 Score:%.3f"%(prec[1],rec[1],f1[1]))
micro_f1 = f1_score(y_test_noAgg,preds,average='micro')
print("Micro-Average F1 Score:",np.round(micro_f1,3))
# Out:
# Random Forest Classifier (tx)
# Precision:0.981
# Recall:0.854
# F1 Score:0.913
# Micro-Average F1 Score: 0.985

# %%
compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)
# Out:
# <ipython-input-22-5fee8f128f02>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)

# %%
clf = RandomForestClassifier(n_estimators=50, max_depth=100,random_state=15).fit(X_train,y_train)
preds = clf.predict(X_test)
prec,rec,f1,num = precision_recall_fscore_support(y_test,preds, average=None)
name = "Random Forest Classifier (tx + agg)"
print("Random Forest Classifier (tx + agg)")
print("Precision:%.3f \nRecall:%.3f \nF1 Score:%.3f"%(prec[1],rec[1],f1[1]))
micro_f1 = f1_score(y_test,preds,average='micro')
print("Micro-Average F1 Score:",micro_f1)
# Out:
# Random Forest Classifier (tx + agg)
# Precision:0.994
# Recall:0.888
# F1 Score:0.938
# Micro-Average F1 Score: 0.988976377952756

# %%
compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)
# Out:
# <ipython-input-24-5fee8f128f02>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)

# %%
reg = LogisticRegression(max_iter=10000).fit(X_train_noAgg,y_train_noAgg)
preds = reg.predict(X_test_noAgg)
prec,rec,f1,num = precision_recall_fscore_support(y_test_noAgg,preds, average=None)
name = "Logistic Regression (tx)"
print("Logistic Regression (tx)")
print("Precision:%.3f \nRecall:%.3f \nF1 Score:%.3f"%(prec[1],rec[1],f1[1]))
micro_f1 = f1_score(y_test_noAgg,preds,average='micro')
print("Micro-Average F1 Score:",micro_f1)
# Out:
# Logistic Regression (tx)
# Precision:0.910
# Recall:0.725
# F1 Score:0.807
# Micro-Average F1 Score: 0.9672870436649964

# %%
compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)
# Out:
# <ipython-input-26-5fee8f128f02>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)

# %%
reg = LogisticRegression(max_iter=10000).fit(X_train,y_train)
preds = reg.predict(X_test)
prec,rec,f1,num = precision_recall_fscore_support(y_test,preds, average=None)
name = "Logistic Regression (tx + agg)"
print("Logistic Regression (tx + agg)")
print("Precision:%.3f \nRecall:%.3f \nF1 Score:%.3f"%(prec[1],rec[1],f1[1]))
micro_f1 = f1_score(y_test,preds,average='micro')
print("Micro-Average F1 Score:",micro_f1)
# Out:
# Logistic Regression (tx + agg)
# Precision:0.848
# Recall:0.791
# F1 Score:0.819
# Micro-Average F1 Score: 0.9669291338582677

# %%
compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)
# Out:
# <ipython-input-28-5fee8f128f02>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)

# %% [markdown]
# ### Classify the unknown transactions

# %%
X = features_unknown[tx_features+agg_features]
preds = pd.DataFrame(clf.predict(X),columns=['class'])
features_unknown = features_unknown[['txId']+tx_features+agg_features].join(preds)
features_unknown['class'] = features_unknown['class'].apply(lambda x: 2 if x==0 else 1)
features_classified = features_known.append(features_unknown)
# Out:
# <ipython-input-29-aa0d6e91674b>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_classified = features_known.append(features_unknown)

# %% [markdown]
# Exploring the distribution of classes in the unknown part. We see there is a big change from the 9 to 1 in the known part to the 73 to 26 in the classified part of the network.
# This is because the proposal of this paper is based around the idea of training with the past for classifiying the future.
# This choice is controversial, but for comparative purpose it is mantained troughout the following study.

# %%
features_unknown['class'].hist()
features_unknown['class'].value_counts(normalize=True) * 100
# Out:
# 2    73.773735
# 1    26.226265
# Name: class, dtype: float64

# %%
features_known['class'].hist()
features_known['class'].value_counts(normalize=True) * 100
# Out:
# 2    90.239241
# 1     9.760759
# Name: class, dtype: float64

# %% [markdown]
# ## Using the tracker function

# %% [markdown]
# ### find a connected network we intend to inspect

# %%
deep_levels = 10
keep = {}
tries = 0
minimum_nodes = 40

while(len(keep) < minimum_nodes):
  seed = get_random_illicit(features)
  keep,edgeList,counter,complete = tracker(deep_levels,seed,edges)
  tries = tries + 1

print("is the graph complete: ",complete)
print("iterations-> ",counter)
print("transactions found->",len(keep))
print("seed : ",seed)
print("seed tried:", tries)
print("transactions : \n")

print(edgeList)
# Out:
# is the graph complete:  True
# iterations->  47
# transactions found-> 44
# seed :  137631
# seed tried: 2
# transactions :
#
#         txId1   txId2
# 57386  137615  110488
# 57542  109525  109524
# 57658  109576  137617
# 57927  110213   85521
# 58302  137608  110488
# 58498  137631  110488
# 58508  115968  137607
# 58531  137607  110488
# 58533   22285  110317
# 58537  137598  110488
# 58688  137625  110488
# 58829  137640  110488
# 58855  137651  110488
# 59285  108172  137609
# 59293  137409  137640
# 59319  137646  110488
# 59524  110213  110210
# 59601  137626  110488
# 59650  118579  110488
# 59672  137655  110488
# 59688  110213  137654
# 59739   22285   16708
# 59826  137599  110488
# 59828  109631  137655
# 59881  109782  109781
# 59979  137613  110488
# 60670  109579  137651
# 60775  137648  110488
# 60895  137620  110488
# 60941  109580  137646
# 61133  137617  110488
# 61457  137659  110488
# 61529  137654  110488
# 61536  137616  110488
# 61690  137667  109782
# 61700  109638  137620
# 61705  109582  137615
# 62063  110488   16708
# 62131  137622  110488
# 62188  109586  137616
# 62299   16708  110497
# 62509  137612  110488
# 62519  137601  110488
# 62598  137591  110488
# 62699  109525  137613
# 62729  137656  110488
# 62754  137609  110488
# 62817  137600  110488
# 62860  137667  110488

# %%
plt.figure(figsize=(10, 10))
import networkx as nx
transaction_graph = nx.from_pandas_edgelist(edgeList,source='txId1', target='txId2')
transaction_type = features[features["txId"].isin(list(transaction_graph.nodes))]["class"].sort_index()
transaction_type = transaction_type.apply(lambda x: 'gray' if x == 0 else x)
transaction_type = transaction_type.apply(lambda x: 'red' if x == 1 else x)
transaction_type = transaction_type.apply(lambda x: 'green' if x == 2 else x)
my_pos = nx.spring_layout(transaction_graph, seed = 100)
nx.draw(transaction_graph,node_size=50, pos=my_pos,node_color=list(transaction_type),width=1)

# %% [markdown]
# ### check the classified results

# %%
plt.figure(figsize=(10, 10))
import networkx as nx
transaction_graph = nx.from_pandas_edgelist(edgeList,source='txId1', target='txId2')
transaction_type = features_classified[features_classified["txId"].isin(list(transaction_graph.nodes))]["class"].sort_index()
transaction_type = transaction_type.apply(lambda x: 'gray' if x == 0 else x)
transaction_type = transaction_type.apply(lambda x: 'red' if x == 1 else x)
transaction_type = transaction_type.apply(lambda x: 'green' if x == 2 else x)
my_pos = nx.spring_layout(transaction_graph, seed = 100)
nx.draw(transaction_graph,node_size=50, pos=my_pos,node_color=list(transaction_type),width=1)

# %% [markdown]
# ## Classification with dense neural networks

# %% [markdown]
# Optimizing the model proved to be very difficult. I think that the problem relies in the time_step based training approach, whic challenges the worthiness of the validation set, and the training set itself.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow import keras

# %%
# Quick function for printing history
def print_learning_curves(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    ax1.plot(history.history["loss"])
    ax1.plot(history.history["val_loss"])
    ax1.legend(["train", "test"], loc="upper right")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")

    ax2.plot(history.history["acc"])
    ax2.plot(history.history["val_acc"])
    ax2.legend(["train", "test"], loc="upper right")
    ax2.set_xlabel("Epochs")
    ax2.set_ylabel("Accuracy")
    plt.show()

# %%
# Parametric feed forward function
def create_ffn(hidden_units, dropout_rate, name=None):
    fnn_layers = []
    seq = keras.Sequential(name=name)

    for units in hidden_units:
        # batch normalization layer
        seq.add(layers.BatchNormalization())
        # add a dropout layer
        seq.add(layers.Dropout(dropout_rate))
        # and finally the dense part
        seq.add(layers.Dense(units, activation=tf.nn.gelu))

    return seq

# %%
def create_baseline_model(hidden_units, num_classes, dropout_rate=0.2):
    inputs = layers.Input(shape=(num_features,), name="input_features")
    x = create_ffn(hidden_units, dropout_rate, name=f"ffn_block1")(inputs)
    for block_idx in range(4):
        # Create an FFN block.
        x1 = create_ffn(hidden_units, dropout_rate, name=f"ffn_block{block_idx + 2}")(x)
        # Add skip connection.
        x = layers.Add(name=f"skip_connection{block_idx + 2}")([x, x1])
    # Compute logits.
    logits = layers.Dense(num_classes, name="logits")(x)
    # Create the model.
    return keras.Model(inputs=inputs, outputs=logits, name="baseline")

# %% [markdown]
# ### Training with only tx_features

# %%
# The executoion of the code here is redundant
# to avoid possible inconsistencies in re-executing the cell
X_noAgg = features_known[tx_features]
y_noAgg = features_known['class']
y_noAgg = y_noAgg.apply(lambda x: 0 if x == 2 else 1 )
X_train_noAgg, X_test_noAgg, y_train_noAgg, y_test_noAgg = train_test_split(X_noAgg,y_noAgg,test_size=0.3,random_state=117,shuffle=True)
#Create a validation set
X_train_noAgg, X_val_noAgg, y_train_noAgg, y_val_noAgg = train_test_split(X_train_noAgg,y_train_noAgg,test_size=0.15,random_state=117,shuffle=True)
print("X_train shape",X_train_noAgg.shape)
print("X_test shape",X_test_noAgg.shape)
print("X_val shape",X_val_noAgg.shape)
print("X_test shape",X_test_noAgg.shape)
print("y_train shape",y_train_noAgg.shape)
print("y_test shape",y_test_noAgg.shape)
print("y_val shape",y_val_noAgg.shape)
# Out:
# X_train shape (27704, 93)
# X_test shape (13970, 93)
# X_val shape (4890, 93)
# X_test shape (13970, 93)
# y_train shape (27704,)
# y_test shape (13970,)
# y_val shape (4890,)

# %%
hidden_units = [90]
learning_rate = 0.001
dropout_rate = 0.3
num_epochs = 200
batch_size = 256

# %%
feature_names = features_known[tx_features].columns
num_features = len(feature_names)
num_classes = len(np.unique(y_train))

# %%
baseline_model = create_baseline_model(hidden_units, 2, dropout_rate)
baseline_model.summary()
# Out:
# Model: "baseline"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_features (InputLayer  [(None, 93)]                 0         []
#  )
#
#  ffn_block1 (Sequential)     (None, 90)                   8832      ['input_features[0][0]']
#
#  ffn_block2 (Sequential)     (None, 90)                   8550      ['ffn_block1[0][0]']
#
#  skip_connection2 (Add)      (None, 90)                   0         ['ffn_block1[0][0]',
#                                                                      'ffn_block2[0][0]']
#
#  ffn_block3 (Sequential)     (None, 90)                   8550      ['skip_connection2[0][0]']
#
#  skip_connection3 (Add)      (None, 90)                   0         ['skip_connection2[0][0]',
#                                                                      'ffn_block3[0][0]']
#
#  ffn_block4 (Sequential)     (None, 90)                   8550      ['skip_connection3[0][0]']
#
#  skip_connection4 (Add)      (None, 90)                   0         ['skip_connection3[0][0]',
#                                                                      'ffn_block4[0][0]']
#
#  ffn_block5 (Sequential)     (None, 90)                   8550      ['skip_connection4[0][0]']
#
#  skip_connection5 (Add)      (None, 90)                   0         ['skip_connection4[0][0]',
#                                                                      'ffn_block5[0][0]']
#
#  logits (Dense)              (None, 2)                    182       ['skip_connection5[0][0]']
#
# ==================================================================================================
# Total params: 43214 (168.80 KB)
# Trainable params: 42308 (165.27 KB)
# Non-trainable params: 906 (3.54 KB)
# __________________________________________________________________________________________________

# %%
# Compile the model.
baseline_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)
# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=30, restore_best_weights=True
)
# Fit the model.
history = baseline_model.fit(
    x=X_train_noAgg,
    y=y_train_noAgg,
    epochs=num_epochs,
    batch_size=batch_size,
    validation_data = (X_val_noAgg,y_val_noAgg),
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/200
# 109/109 [==============================] - 5s 15ms/step - loss: 0.2332 - acc: 0.9195 - val_loss: 0.1988 - val_acc: 0.9395
# Epoch 2/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1746 - acc: 0.9416 - val_loss: 0.1436 - val_acc: 0.9609
# Epoch 3/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.1607 - acc: 0.9477 - val_loss: 0.1315 - val_acc: 0.9665
# Epoch 4/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.1481 - acc: 0.9531 - val_loss: 0.1215 - val_acc: 0.9650
# Epoch 5/200
# 109/109 [==============================] - 2s 15ms/step - loss: 0.1426 - acc: 0.9550 - val_loss: 0.1186 - val_acc: 0.9679
# Epoch 6/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1383 - acc: 0.9565 - val_loss: 0.1171 - val_acc: 0.9634
# Epoch 7/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1331 - acc: 0.9583 - val_loss: 0.1193 - val_acc: 0.9685
# Epoch 8/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1286 - acc: 0.9600 - val_loss: 0.1110 - val_acc: 0.9679
# Epoch 9/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1247 - acc: 0.9610 - val_loss: 0.1151 - val_acc: 0.9693
# Epoch 10/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1255 - acc: 0.9602 - val_loss: 0.1139 - val_acc: 0.9703
# Epoch 11/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1222 - acc: 0.9625 - val_loss: 0.1187 - val_acc: 0.9697
# Epoch 12/200
# 109/109 [==============================] - 2s 14ms/step - loss: 0.1207 - acc: 0.9618 - val_loss: 0.1232 - val_acc: 0.9697
# Epoch 13/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.1183 - acc: 0.9641 - val_loss: 0.1163 - val_acc: 0.9703
# Epoch 14/200
# 109/109 [==============================] - 2s 14ms/step - loss: 0.1164 - acc: 0.9637 - val_loss: 0.1077 - val_acc: 0.9677
# Epoch 15/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.1125 - acc: 0.9653 - val_loss: 0.1067 - val_acc: 0.9693
# Epoch 16/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.1121 - acc: 0.9645 - val_loss: 0.1244 - val_acc: 0.9708
# Epoch 17/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1110 - acc: 0.9655 - val_loss: 0.1156 - val_acc: 0.9708
# Epoch 18/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.1118 - acc: 0.9662 - val_loss: 0.1169 - val_acc: 0.9699
# Epoch 19/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1101 - acc: 0.9660 - val_loss: 0.1340 - val_acc: 0.9697
# Epoch 20/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1098 - acc: 0.9659 - val_loss: 0.1619 - val_acc: 0.9098
# Epoch 21/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1055 - acc: 0.9673 - val_loss: 0.1407 - val_acc: 0.9597
# Epoch 22/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.1068 - acc: 0.9667 - val_loss: 0.1067 - val_acc: 0.9703
# Epoch 23/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1043 - acc: 0.9673 - val_loss: 0.1179 - val_acc: 0.9703
# Epoch 24/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1031 - acc: 0.9676 - val_loss: 0.1175 - val_acc: 0.9699
# Epoch 25/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1044 - acc: 0.9681 - val_loss: 0.1047 - val_acc: 0.9706
# Epoch 26/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1015 - acc: 0.9681 - val_loss: 0.1164 - val_acc: 0.9712
# Epoch 27/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1019 - acc: 0.9681 - val_loss: 0.1181 - val_acc: 0.9701
# Epoch 28/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.1019 - acc: 0.9675 - val_loss: 0.1270 - val_acc: 0.9708
# Epoch 29/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0997 - acc: 0.9690 - val_loss: 0.1203 - val_acc: 0.9697
# Epoch 30/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0996 - acc: 0.9700 - val_loss: 0.1279 - val_acc: 0.9689
# Epoch 31/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.0979 - acc: 0.9688 - val_loss: 0.1109 - val_acc: 0.9708
# Epoch 32/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0964 - acc: 0.9695 - val_loss: 0.1335 - val_acc: 0.9413
# Epoch 33/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0989 - acc: 0.9683 - val_loss: 0.1300 - val_acc: 0.9658
# Epoch 34/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0961 - acc: 0.9700 - val_loss: 0.1245 - val_acc: 0.9703
# Epoch 35/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0975 - acc: 0.9692 - val_loss: 0.1097 - val_acc: 0.9710
# Epoch 36/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0972 - acc: 0.9694 - val_loss: 0.1293 - val_acc: 0.9699
# Epoch 37/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0961 - acc: 0.9701 - val_loss: 0.1280 - val_acc: 0.9689
# Epoch 38/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.0964 - acc: 0.9687 - val_loss: 0.1258 - val_acc: 0.9695
# Epoch 39/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0962 - acc: 0.9696 - val_loss: 0.1141 - val_acc: 0.9716
# Epoch 40/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0921 - acc: 0.9701 - val_loss: 0.1437 - val_acc: 0.9372
# Epoch 41/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0948 - acc: 0.9697 - val_loss: 0.1287 - val_acc: 0.9446
# Epoch 42/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0946 - acc: 0.9698 - val_loss: 0.0931 - val_acc: 0.9726
# Epoch 43/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0938 - acc: 0.9692 - val_loss: 0.1149 - val_acc: 0.9703
# Epoch 44/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0931 - acc: 0.9708 - val_loss: 0.1063 - val_acc: 0.9708
# Epoch 45/200
# 109/109 [==============================] - 2s 15ms/step - loss: 0.0919 - acc: 0.9703 - val_loss: 0.1253 - val_acc: 0.9521
# Epoch 46/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0910 - acc: 0.9699 - val_loss: 0.1068 - val_acc: 0.9708
# Epoch 47/200
# 109/109 [==============================] - 2s 14ms/step - loss: 0.0917 - acc: 0.9707 - val_loss: 0.1215 - val_acc: 0.9706
# Epoch 48/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0904 - acc: 0.9710 - val_loss: 0.1353 - val_acc: 0.9421
# Epoch 49/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0903 - acc: 0.9709 - val_loss: 0.1073 - val_acc: 0.9708
# Epoch 50/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0919 - acc: 0.9703 - val_loss: 0.1421 - val_acc: 0.9346
# Epoch 51/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0891 - acc: 0.9716 - val_loss: 0.1097 - val_acc: 0.9701
# Epoch 52/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0923 - acc: 0.9704 - val_loss: 0.1066 - val_acc: 0.9714
# Epoch 53/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0938 - acc: 0.9695 - val_loss: 0.0962 - val_acc: 0.9716
# Epoch 54/200
# 109/109 [==============================] - 2s 15ms/step - loss: 0.0902 - acc: 0.9704 - val_loss: 0.0972 - val_acc: 0.9712
# Epoch 55/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.0900 - acc: 0.9709 - val_loss: 0.1021 - val_acc: 0.9710
# Epoch 56/200
# 109/109 [==============================] - 2s 15ms/step - loss: 0.0889 - acc: 0.9711 - val_loss: 0.0979 - val_acc: 0.9703
# Epoch 57/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0893 - acc: 0.9716 - val_loss: 0.1287 - val_acc: 0.9699
# Epoch 58/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0889 - acc: 0.9713 - val_loss: 0.1116 - val_acc: 0.9706
# Epoch 59/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0866 - acc: 0.9717 - val_loss: 0.0941 - val_acc: 0.9718
# Epoch 60/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0879 - acc: 0.9712 - val_loss: 0.1053 - val_acc: 0.9718
# Epoch 61/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0876 - acc: 0.9715 - val_loss: 0.0986 - val_acc: 0.9714
# Epoch 62/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0859 - acc: 0.9722 - val_loss: 0.1296 - val_acc: 0.9689
# Epoch 63/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0853 - acc: 0.9720 - val_loss: 0.1232 - val_acc: 0.9697
# Epoch 64/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0861 - acc: 0.9720 - val_loss: 0.1018 - val_acc: 0.9720
# Epoch 65/200
# 109/109 [==============================] - 1s 13ms/step - loss: 0.0870 - acc: 0.9721 - val_loss: 0.1075 - val_acc: 0.9712
# Epoch 66/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0856 - acc: 0.9720 - val_loss: 0.1006 - val_acc: 0.9712
# Epoch 67/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0868 - acc: 0.9721 - val_loss: 0.1103 - val_acc: 0.9714
# Epoch 68/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0862 - acc: 0.9726 - val_loss: 0.0987 - val_acc: 0.9724
# Epoch 69/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0855 - acc: 0.9721 - val_loss: 0.1053 - val_acc: 0.9718
# Epoch 70/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0879 - acc: 0.9713 - val_loss: 0.0983 - val_acc: 0.9714
# Epoch 71/200
# 109/109 [==============================] - 1s 12ms/step - loss: 0.0854 - acc: 0.9718 - val_loss: 0.1129 - val_acc: 0.9699
# Epoch 72/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0861 - acc: 0.9720 - val_loss: 0.1449 - val_acc: 0.9452

# %%
print_learning_curves(history)

# %% [markdown]
# ### test the results

# %%
preds = baseline_model.predict(X_test_noAgg)
norm_preds = sklearn.preprocessing.normalize(preds)

y_predicted = []
for pred in norm_preds:
  if pred[0] > pred[1]:
    y_predicted.append(0)
  else :
    y_predicted.append(1)
# Out:
# 437/437 [==============================] - 1s 2ms/step

# %%
prec,rec,f1,num = precision_recall_fscore_support(y_test,y_predicted, average=None)
name = "Dense neural network (tx)"
print("Dense neural network (tx)")
print("Precision:%.3f \nRecall:%.3f \nF1 Score:%.3f"%(prec[1],rec[1],f1[1]))
micro_f1 = f1_score(y_test,y_predicted,average='micro')
print("Micro-Average F1 Score:",micro_f1)
# Out:
# Dense neural network (tx)
# Precision:0.969
# Recall:0.754
# F1 Score:0.848
# Micro-Average F1 Score: 0.9745168217609163

# %%
compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)
# Out:
# <ipython-input-47-5fee8f128f02>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)

# %% [markdown]
# ### Training with both tx_features and agg_features

# %%
X = features_known[tx_features+agg_features]
y = features_known['class']
# this is important
y = y.apply(lambda x: 0 if x == 2 else 1 )
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=117,shuffle=True)
#Create a validation set
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.15,random_state=117,shuffle=True)
print("X_train shape",X_train.shape)
print("X_test shape",X_test.shape)
print("X_val shape",X_val.shape)
print("X_test shape",X_test.shape)
print("y_train shape",y_train.shape)
print("y_test shape",y_test.shape)
print("y_val shape",y_val.shape)
# Out:
# X_train shape (27704, 165)
# X_test shape (13970, 165)
# X_val shape (4890, 165)
# X_test shape (13970, 165)
# y_train shape (27704,)
# y_test shape (13970,)
# y_val shape (4890,)

# %%
hidden_units = [130]
learning_rate = 0.001
dropout_rate = 0.4
num_epochs = 200
batch_size = 256

# %%
feature_names = features_known[tx_features+agg_features].columns
num_features = len(feature_names)
num_classes = len(np.unique(y_train))

# %%
baseline_model = create_baseline_model(hidden_units, 2, dropout_rate)
baseline_model.summary()
# Out:
# Model: "baseline"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_features (InputLayer  [(None, 165)]                0         []
#  )
#
#  ffn_block1 (Sequential)     (None, 130)                  22240     ['input_features[0][0]']
#
#  ffn_block2 (Sequential)     (None, 130)                  17550     ['ffn_block1[0][0]']
#
#  skip_connection2 (Add)      (None, 130)                  0         ['ffn_block1[0][0]',
#                                                                      'ffn_block2[0][0]']
#
#  ffn_block3 (Sequential)     (None, 130)                  17550     ['skip_connection2[0][0]']
#
#  skip_connection3 (Add)      (None, 130)                  0         ['skip_connection2[0][0]',
#                                                                      'ffn_block3[0][0]']
#
#  ffn_block4 (Sequential)     (None, 130)                  17550     ['skip_connection3[0][0]']
#
#  skip_connection4 (Add)      (None, 130)                  0         ['skip_connection3[0][0]',
#                                                                      'ffn_block4[0][0]']
#
#  ffn_block5 (Sequential)     (None, 130)                  17550     ['skip_connection4[0][0]']
#
#  skip_connection5 (Add)      (None, 130)                  0         ['skip_connection4[0][0]',
#                                                                      'ffn_block5[0][0]']
#
#  logits (Dense)              (None, 2)                    262       ['skip_connection5[0][0]']
#
# ==================================================================================================
# Total params: 92702 (362.12 KB)
# Trainable params: 91332 (356.77 KB)
# Non-trainable params: 1370 (5.35 KB)
# __________________________________________________________________________________________________

# %%
# Compile the model.
baseline_model.compile(
    optimizer=keras.optimizers.Adam(learning_rate),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
)
# Create an early stopping callback.
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=50, restore_best_weights=True
)
# Fit the model.
history = baseline_model.fit(
    x=X_train,
    y=y_train,
    epochs=num_epochs,
    batch_size=batch_size,
    validation_data = (X_val,y_val),
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/200
# 109/109 [==============================] - 6s 19ms/step - loss: 0.3419 - acc: 0.8871 - val_loss: 0.1728 - val_acc: 0.9434
# Epoch 2/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1784 - acc: 0.9381 - val_loss: 0.1459 - val_acc: 0.9526
# Epoch 3/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1608 - acc: 0.9449 - val_loss: 0.1353 - val_acc: 0.9556
# Epoch 4/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1458 - acc: 0.9515 - val_loss: 0.1215 - val_acc: 0.9603
# Epoch 5/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1361 - acc: 0.9541 - val_loss: 0.1202 - val_acc: 0.9611
# Epoch 6/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.1297 - acc: 0.9558 - val_loss: 0.1100 - val_acc: 0.9648
# Epoch 7/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.1246 - acc: 0.9580 - val_loss: 0.1063 - val_acc: 0.9656
# Epoch 8/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1224 - acc: 0.9592 - val_loss: 0.1096 - val_acc: 0.9620
# Epoch 9/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1160 - acc: 0.9613 - val_loss: 0.1109 - val_acc: 0.9609
# Epoch 10/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1126 - acc: 0.9631 - val_loss: 0.1006 - val_acc: 0.9687
# Epoch 11/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1112 - acc: 0.9623 - val_loss: 0.0997 - val_acc: 0.9667
# Epoch 12/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.1096 - acc: 0.9621 - val_loss: 0.0969 - val_acc: 0.9665
# Epoch 13/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.1043 - acc: 0.9638 - val_loss: 0.0935 - val_acc: 0.9706
# Epoch 14/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1037 - acc: 0.9657 - val_loss: 0.0926 - val_acc: 0.9697
# Epoch 15/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1021 - acc: 0.9660 - val_loss: 0.0851 - val_acc: 0.9724
# Epoch 16/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0974 - acc: 0.9665 - val_loss: 0.0902 - val_acc: 0.9720
# Epoch 17/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1003 - acc: 0.9668 - val_loss: 0.0871 - val_acc: 0.9728
# Epoch 18/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0962 - acc: 0.9670 - val_loss: 0.0898 - val_acc: 0.9708
# Epoch 19/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.0970 - acc: 0.9663 - val_loss: 0.0809 - val_acc: 0.9746
# Epoch 20/200
# 109/109 [==============================] - 2s 23ms/step - loss: 0.0924 - acc: 0.9688 - val_loss: 0.0829 - val_acc: 0.9746
# Epoch 21/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0936 - acc: 0.9693 - val_loss: 0.0836 - val_acc: 0.9732
# Epoch 22/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0916 - acc: 0.9687 - val_loss: 0.0865 - val_acc: 0.9728
# Epoch 23/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0903 - acc: 0.9696 - val_loss: 0.0797 - val_acc: 0.9744
# Epoch 24/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0861 - acc: 0.9707 - val_loss: 0.0776 - val_acc: 0.9767
# Epoch 25/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0853 - acc: 0.9709 - val_loss: 0.0764 - val_acc: 0.9769
# Epoch 26/200
# 109/109 [==============================] - 3s 27ms/step - loss: 0.0854 - acc: 0.9720 - val_loss: 0.0783 - val_acc: 0.9753
# Epoch 27/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0882 - acc: 0.9714 - val_loss: 0.0776 - val_acc: 0.9765
# Epoch 28/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0835 - acc: 0.9715 - val_loss: 0.0762 - val_acc: 0.9751
# Epoch 29/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0844 - acc: 0.9723 - val_loss: 0.0720 - val_acc: 0.9773
# Epoch 30/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0826 - acc: 0.9717 - val_loss: 0.0752 - val_acc: 0.9775
# Epoch 31/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0818 - acc: 0.9725 - val_loss: 0.0764 - val_acc: 0.9755
# Epoch 32/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.0835 - acc: 0.9728 - val_loss: 0.0757 - val_acc: 0.9767
# Epoch 33/200
# 109/109 [==============================] - 3s 24ms/step - loss: 0.0794 - acc: 0.9728 - val_loss: 0.0741 - val_acc: 0.9769
# Epoch 34/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0801 - acc: 0.9738 - val_loss: 0.0751 - val_acc: 0.9773
# Epoch 35/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0781 - acc: 0.9734 - val_loss: 0.0753 - val_acc: 0.9787
# Epoch 36/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0779 - acc: 0.9729 - val_loss: 0.0731 - val_acc: 0.9769
# Epoch 37/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0772 - acc: 0.9742 - val_loss: 0.0798 - val_acc: 0.9751
# Epoch 38/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0782 - acc: 0.9732 - val_loss: 0.0843 - val_acc: 0.9736
# Epoch 39/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0743 - acc: 0.9753 - val_loss: 0.0707 - val_acc: 0.9777
# Epoch 40/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0711 - acc: 0.9751 - val_loss: 0.0692 - val_acc: 0.9787
# Epoch 41/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0735 - acc: 0.9748 - val_loss: 0.0691 - val_acc: 0.9806
# Epoch 42/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0731 - acc: 0.9756 - val_loss: 0.0776 - val_acc: 0.9783
# Epoch 43/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0722 - acc: 0.9750 - val_loss: 0.0729 - val_acc: 0.9802
# Epoch 44/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0743 - acc: 0.9750 - val_loss: 0.0716 - val_acc: 0.9785
# Epoch 45/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0733 - acc: 0.9739 - val_loss: 0.0728 - val_acc: 0.9793
# Epoch 46/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0722 - acc: 0.9748 - val_loss: 0.0700 - val_acc: 0.9800
# Epoch 47/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0740 - acc: 0.9758 - val_loss: 0.0672 - val_acc: 0.9791
# Epoch 48/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0694 - acc: 0.9755 - val_loss: 0.0746 - val_acc: 0.9781
# Epoch 49/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0682 - acc: 0.9769 - val_loss: 0.0679 - val_acc: 0.9793
# Epoch 50/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0680 - acc: 0.9761 - val_loss: 0.0677 - val_acc: 0.9791
# Epoch 51/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0722 - acc: 0.9761 - val_loss: 0.0717 - val_acc: 0.9779
# Epoch 52/200
# 109/109 [==============================] - 3s 30ms/step - loss: 0.0687 - acc: 0.9770 - val_loss: 0.0737 - val_acc: 0.9775
# Epoch 53/200
# 109/109 [==============================] - 3s 24ms/step - loss: 0.0690 - acc: 0.9764 - val_loss: 0.0682 - val_acc: 0.9796
# Epoch 54/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0690 - acc: 0.9764 - val_loss: 0.0716 - val_acc: 0.9789
# Epoch 55/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0688 - acc: 0.9760 - val_loss: 0.0757 - val_acc: 0.9759
# Epoch 56/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0682 - acc: 0.9768 - val_loss: 0.0695 - val_acc: 0.9773
# Epoch 57/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0663 - acc: 0.9762 - val_loss: 0.0688 - val_acc: 0.9783
# Epoch 58/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0681 - acc: 0.9760 - val_loss: 0.0702 - val_acc: 0.9798
# Epoch 59/200
# 109/109 [==============================] - 3s 27ms/step - loss: 0.0685 - acc: 0.9764 - val_loss: 0.0749 - val_acc: 0.9765
# Epoch 60/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0664 - acc: 0.9771 - val_loss: 0.0744 - val_acc: 0.9767
# Epoch 61/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0656 - acc: 0.9774 - val_loss: 0.0692 - val_acc: 0.9789
# Epoch 62/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0657 - acc: 0.9769 - val_loss: 0.0694 - val_acc: 0.9789
# Epoch 63/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0655 - acc: 0.9775 - val_loss: 0.0659 - val_acc: 0.9800
# Epoch 64/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0660 - acc: 0.9771 - val_loss: 0.0698 - val_acc: 0.9775
# Epoch 65/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0632 - acc: 0.9779 - val_loss: 0.0684 - val_acc: 0.9789
# Epoch 66/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.0652 - acc: 0.9776 - val_loss: 0.0692 - val_acc: 0.9781
# Epoch 67/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0646 - acc: 0.9780 - val_loss: 0.0675 - val_acc: 0.9791
# Epoch 68/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0649 - acc: 0.9786 - val_loss: 0.0693 - val_acc: 0.9789
# Epoch 69/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0636 - acc: 0.9777 - val_loss: 0.0669 - val_acc: 0.9789
# Epoch 70/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0627 - acc: 0.9778 - val_loss: 0.0686 - val_acc: 0.9793
# Epoch 71/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0633 - acc: 0.9783 - val_loss: 0.0711 - val_acc: 0.9791
# Epoch 72/200
# 109/109 [==============================] - 2s 22ms/step - loss: 0.0612 - acc: 0.9783 - val_loss: 0.0770 - val_acc: 0.9781
# Epoch 73/200
# 109/109 [==============================] - 2s 22ms/step - loss: 0.0632 - acc: 0.9782 - val_loss: 0.0710 - val_acc: 0.9798
# Epoch 74/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0613 - acc: 0.9787 - val_loss: 0.0691 - val_acc: 0.9785
# Epoch 75/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0607 - acc: 0.9793 - val_loss: 0.0727 - val_acc: 0.9789
# Epoch 76/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0596 - acc: 0.9786 - val_loss: 0.0744 - val_acc: 0.9773
# Epoch 77/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0613 - acc: 0.9786 - val_loss: 0.0687 - val_acc: 0.9798
# Epoch 78/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0626 - acc: 0.9789 - val_loss: 0.0691 - val_acc: 0.9798
# Epoch 79/200
# 109/109 [==============================] - 3s 27ms/step - loss: 0.0611 - acc: 0.9794 - val_loss: 0.0722 - val_acc: 0.9796
# Epoch 80/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0593 - acc: 0.9795 - val_loss: 0.0668 - val_acc: 0.9808
# Epoch 81/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0580 - acc: 0.9793 - val_loss: 0.0672 - val_acc: 0.9785
# Epoch 82/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0604 - acc: 0.9801 - val_loss: 0.0729 - val_acc: 0.9771
# Epoch 83/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0592 - acc: 0.9800 - val_loss: 0.0661 - val_acc: 0.9791
# Epoch 84/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0581 - acc: 0.9808 - val_loss: 0.0692 - val_acc: 0.9783
# Epoch 85/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.0578 - acc: 0.9800 - val_loss: 0.0657 - val_acc: 0.9793
# Epoch 86/200
# 109/109 [==============================] - 3s 24ms/step - loss: 0.0564 - acc: 0.9801 - val_loss: 0.0705 - val_acc: 0.9781
# Epoch 87/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0605 - acc: 0.9791 - val_loss: 0.0724 - val_acc: 0.9781
# Epoch 88/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0562 - acc: 0.9798 - val_loss: 0.0741 - val_acc: 0.9777
# Epoch 89/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0569 - acc: 0.9796 - val_loss: 0.0647 - val_acc: 0.9800
# Epoch 90/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0588 - acc: 0.9798 - val_loss: 0.0677 - val_acc: 0.9787
# Epoch 91/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0571 - acc: 0.9799 - val_loss: 0.0698 - val_acc: 0.9793
# Epoch 92/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0547 - acc: 0.9802 - val_loss: 0.0662 - val_acc: 0.9798
# Epoch 93/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0580 - acc: 0.9791 - val_loss: 0.0671 - val_acc: 0.9796
# Epoch 94/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0564 - acc: 0.9803 - val_loss: 0.0683 - val_acc: 0.9798
# Epoch 95/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0560 - acc: 0.9800 - val_loss: 0.0683 - val_acc: 0.9789
# Epoch 96/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0547 - acc: 0.9809 - val_loss: 0.0716 - val_acc: 0.9787
# Epoch 97/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0585 - acc: 0.9797 - val_loss: 0.0701 - val_acc: 0.9787
# Epoch 98/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0527 - acc: 0.9809 - val_loss: 0.0648 - val_acc: 0.9804
# Epoch 99/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0562 - acc: 0.9806 - val_loss: 0.0680 - val_acc: 0.9793
# Epoch 100/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0560 - acc: 0.9803 - val_loss: 0.0706 - val_acc: 0.9781
# Epoch 101/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0541 - acc: 0.9820 - val_loss: 0.0676 - val_acc: 0.9802
# Epoch 102/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0558 - acc: 0.9798 - val_loss: 0.0759 - val_acc: 0.9779
# Epoch 103/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0567 - acc: 0.9796 - val_loss: 0.0701 - val_acc: 0.9791
# Epoch 104/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0535 - acc: 0.9808 - val_loss: 0.0737 - val_acc: 0.9783
# Epoch 105/200
# 109/109 [==============================] - 3s 24ms/step - loss: 0.0544 - acc: 0.9801 - val_loss: 0.0681 - val_acc: 0.9785
# Epoch 106/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.0566 - acc: 0.9801 - val_loss: 0.0680 - val_acc: 0.9789
# Epoch 107/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0545 - acc: 0.9811 - val_loss: 0.0660 - val_acc: 0.9800
# Epoch 108/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0568 - acc: 0.9798 - val_loss: 0.0670 - val_acc: 0.9783
# Epoch 109/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0537 - acc: 0.9811 - val_loss: 0.0662 - val_acc: 0.9789
# Epoch 110/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0542 - acc: 0.9810 - val_loss: 0.0668 - val_acc: 0.9787
# Epoch 111/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0560 - acc: 0.9806 - val_loss: 0.0672 - val_acc: 0.9800
# Epoch 112/200
# 109/109 [==============================] - 3s 27ms/step - loss: 0.0535 - acc: 0.9817 - val_loss: 0.0719 - val_acc: 0.9773
# Epoch 113/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0544 - acc: 0.9806 - val_loss: 0.0667 - val_acc: 0.9793
# Epoch 114/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0537 - acc: 0.9812 - val_loss: 0.0687 - val_acc: 0.9777
# Epoch 115/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0531 - acc: 0.9808 - val_loss: 0.0700 - val_acc: 0.9796
# Epoch 116/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0525 - acc: 0.9822 - val_loss: 0.0708 - val_acc: 0.9779
# Epoch 117/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0537 - acc: 0.9822 - val_loss: 0.0686 - val_acc: 0.9771
# Epoch 118/200
# 109/109 [==============================] - 3s 29ms/step - loss: 0.0518 - acc: 0.9815 - val_loss: 0.0701 - val_acc: 0.9777
# Epoch 119/200
# 109/109 [==============================] - 4s 34ms/step - loss: 0.0512 - acc: 0.9828 - val_loss: 0.0689 - val_acc: 0.9781
# Epoch 120/200
# 109/109 [==============================] - 3s 24ms/step - loss: 0.0533 - acc: 0.9809 - val_loss: 0.0702 - val_acc: 0.9787
# Epoch 121/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0519 - acc: 0.9813 - val_loss: 0.0641 - val_acc: 0.9791
# Epoch 122/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0539 - acc: 0.9810 - val_loss: 0.0666 - val_acc: 0.9800
# Epoch 123/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0515 - acc: 0.9818 - val_loss: 0.0646 - val_acc: 0.9804
# Epoch 124/200
# 109/109 [==============================] - 2s 22ms/step - loss: 0.0514 - acc: 0.9810 - val_loss: 0.0691 - val_acc: 0.9775
# Epoch 125/200
# 109/109 [==============================] - 3s 24ms/step - loss: 0.0505 - acc: 0.9825 - val_loss: 0.0638 - val_acc: 0.9806
# Epoch 126/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0508 - acc: 0.9812 - val_loss: 0.0675 - val_acc: 0.9798
# Epoch 127/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0509 - acc: 0.9827 - val_loss: 0.0663 - val_acc: 0.9787
# Epoch 128/200
# 109/109 [==============================] - 2s 18ms/step - loss: 0.0513 - acc: 0.9814 - val_loss: 0.0646 - val_acc: 0.9808
# Epoch 129/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0540 - acc: 0.9815 - val_loss: 0.0643 - val_acc: 0.9804
# Epoch 130/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0521 - acc: 0.9810 - val_loss: 0.0722 - val_acc: 0.9789
# Epoch 131/200
# 109/109 [==============================] - 3s 26ms/step - loss: 0.0520 - acc: 0.9818 - val_loss: 0.0674 - val_acc: 0.9798
# Epoch 132/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0519 - acc: 0.9815 - val_loss: 0.0720 - val_acc: 0.9775
# Epoch 133/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0524 - acc: 0.9814 - val_loss: 0.0691 - val_acc: 0.9800
# Epoch 134/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0494 - acc: 0.9826 - val_loss: 0.0671 - val_acc: 0.9802
# Epoch 135/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0498 - acc: 0.9819 - val_loss: 0.0690 - val_acc: 0.9793
# Epoch 136/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0529 - acc: 0.9812 - val_loss: 0.0671 - val_acc: 0.9804
# Epoch 137/200
# 109/109 [==============================] - 2s 21ms/step - loss: 0.0513 - acc: 0.9818 - val_loss: 0.0712 - val_acc: 0.9793
# Epoch 138/200
# 109/109 [==============================] - 3s 24ms/step - loss: 0.0494 - acc: 0.9825 - val_loss: 0.0732 - val_acc: 0.9783
# Epoch 139/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0515 - acc: 0.9824 - val_loss: 0.0716 - val_acc: 0.9789
# Epoch 140/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0514 - acc: 0.9815 - val_loss: 0.0709 - val_acc: 0.9783
# Epoch 141/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0503 - acc: 0.9818 - val_loss: 0.0696 - val_acc: 0.9791
# Epoch 142/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0480 - acc: 0.9829 - val_loss: 0.0710 - val_acc: 0.9787
# Epoch 143/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0494 - acc: 0.9829 - val_loss: 0.0687 - val_acc: 0.9789
# Epoch 144/200
# 109/109 [==============================] - 3s 25ms/step - loss: 0.0492 - acc: 0.9823 - val_loss: 0.0676 - val_acc: 0.9783
# Epoch 145/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.0473 - acc: 0.9830 - val_loss: 0.0713 - val_acc: 0.9793
# Epoch 146/200
# 109/109 [==============================] - 3s 31ms/step - loss: 0.0486 - acc: 0.9834 - val_loss: 0.0731 - val_acc: 0.9791
# Epoch 147/200
# 109/109 [==============================] - 3s 32ms/step - loss: 0.0499 - acc: 0.9821 - val_loss: 0.0670 - val_acc: 0.9789
# Epoch 148/200
# 109/109 [==============================] - 4s 35ms/step - loss: 0.0486 - acc: 0.9827 - val_loss: 0.0688 - val_acc: 0.9793
# Epoch 149/200
# 109/109 [==============================] - 4s 37ms/step - loss: 0.0461 - acc: 0.9825 - val_loss: 0.0692 - val_acc: 0.9779
# Epoch 150/200
# 109/109 [==============================] - 4s 33ms/step - loss: 0.0499 - acc: 0.9812 - val_loss: 0.0684 - val_acc: 0.9812
# Epoch 151/200
# 109/109 [==============================] - 3s 32ms/step - loss: 0.0482 - acc: 0.9825 - val_loss: 0.0709 - val_acc: 0.9781
# Epoch 152/200
# 109/109 [==============================] - 4s 40ms/step - loss: 0.0481 - acc: 0.9829 - val_loss: 0.0686 - val_acc: 0.9804
# Epoch 153/200
# 109/109 [==============================] - 3s 32ms/step - loss: 0.0511 - acc: 0.9813 - val_loss: 0.0666 - val_acc: 0.9789
# Epoch 154/200
# 109/109 [==============================] - 3s 32ms/step - loss: 0.0489 - acc: 0.9830 - val_loss: 0.0753 - val_acc: 0.9777
# Epoch 155/200
# 109/109 [==============================] - 4s 35ms/step - loss: 0.0479 - acc: 0.9827 - val_loss: 0.0685 - val_acc: 0.9816
# Epoch 156/200
# 109/109 [==============================] - 4s 38ms/step - loss: 0.0468 - acc: 0.9833 - val_loss: 0.0669 - val_acc: 0.9810
# Epoch 157/200
# 109/109 [==============================] - 3s 31ms/step - loss: 0.0479 - acc: 0.9829 - val_loss: 0.0692 - val_acc: 0.9793
# Epoch 158/200
# 109/109 [==============================] - 3s 32ms/step - loss: 0.0464 - acc: 0.9839 - val_loss: 0.0670 - val_acc: 0.9796
# Epoch 159/200
# 109/109 [==============================] - 4s 38ms/step - loss: 0.0455 - acc: 0.9842 - val_loss: 0.0695 - val_acc: 0.9789
# Epoch 160/200
# 109/109 [==============================] - 4s 34ms/step - loss: 0.0480 - acc: 0.9827 - val_loss: 0.0656 - val_acc: 0.9793
# Epoch 161/200
# 109/109 [==============================] - 4s 36ms/step - loss: 0.0461 - acc: 0.9831 - val_loss: 0.0726 - val_acc: 0.9761
# Epoch 162/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0455 - acc: 0.9832 - val_loss: 0.0700 - val_acc: 0.9763
# Epoch 163/200
# 109/109 [==============================] - 2s 19ms/step - loss: 0.0503 - acc: 0.9820 - val_loss: 0.0698 - val_acc: 0.9775
# Epoch 164/200
# 109/109 [==============================] - 3s 27ms/step - loss: 0.0465 - acc: 0.9828 - val_loss: 0.0710 - val_acc: 0.9793
# Epoch 165/200
# 109/109 [==============================] - 3s 27ms/step - loss: 0.0464 - acc: 0.9834 - val_loss: 0.0699 - val_acc: 0.9785
# Epoch 166/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0452 - acc: 0.9842 - val_loss: 0.0691 - val_acc: 0.9793
# Epoch 167/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0439 - acc: 0.9842 - val_loss: 0.0754 - val_acc: 0.9781
# Epoch 168/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0481 - acc: 0.9817 - val_loss: 0.0664 - val_acc: 0.9808
# Epoch 169/200
# 109/109 [==============================] - 2s 20ms/step - loss: 0.0491 - acc: 0.9830 - val_loss: 0.0676 - val_acc: 0.9806
# Epoch 170/200
# 109/109 [==============================] - 3s 24ms/step - loss: 0.0483 - acc: 0.9822 - val_loss: 0.0713 - val_acc: 0.9777
# Epoch 171/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0439 - acc: 0.9843 - val_loss: 0.0728 - val_acc: 0.9798
# Epoch 172/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0472 - acc: 0.9838 - val_loss: 0.0672 - val_acc: 0.9810
# Epoch 173/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0448 - acc: 0.9840 - val_loss: 0.0760 - val_acc: 0.9777
# Epoch 174/200
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0479 - acc: 0.9826 - val_loss: 0.0705 - val_acc: 0.9800
# Epoch 175/200
# 109/109 [==============================] - 2s 17ms/step - loss: 0.0449 - acc: 0.9841 - val_loss: 0.0706 - val_acc: 0.9806

# %%
print_learning_curves(history)

# %% [markdown]
# ### test the results

# %%
preds = baseline_model.predict(X_test)
norm_preds = sklearn.preprocessing.normalize(preds)

y_predicted = []
for pred in norm_preds:
  if pred[0] > pred[1]:
    y_predicted.append(0)
  else :
    y_predicted.append(1)
# Out:
# 437/437 [==============================] - 1s 2ms/step

# %%
prec,rec,f1,num = precision_recall_fscore_support(y_test,y_predicted, average=None)
name = "Dense neural network (tx + agg)"
print("Dense neural network (tx + agg)")
print("Precision:%.3f \nRecall:%.3f \nF1 Score:%.3f"%(prec[1],rec[1],f1[1]))
micro_f1 = f1_score(y_test,y_predicted,average='micro')
print("Micro-Average F1 Score:",micro_f1)
# Out:
# Dense neural network (tx + agg)
# Precision:0.962
# Recall:0.861
# F1 Score:0.909
# Micro-Average F1 Score: 0.9836793128131711

# %%
compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)
# Out:
# <ipython-input-56-5fee8f128f02>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compare = compare.append({'model':name,'Precision':np.round(prec[1],3),'Recall':np.round(rec[1],3),'F1 Score':np.round(f1[1],3),'M.A F1 Score':np.round(micro_f1,3)}, ignore_index=True)

# %% [markdown]
# ### classify the unknown transactions with the Neural network

# %%
X = features_unknown[tx_features+agg_features]
preds = baseline_model.predict(X)

norm_preds = sklearn.preprocessing.normalize(preds)

y_predicted = []
for pred in norm_preds:
  if pred[0] > pred[1]:
    y_predicted.append(0)
  else :
    y_predicted.append(1)

preds = pd.DataFrame(y_predicted,columns=['class'])
features_unknown = features_unknown[['txId']+tx_features+agg_features].join(preds)
features_unknown['class'] = features_unknown['class'].apply(lambda x: 2 if x==0 else 1)
features_classified = features_known.append(features_unknown)
# Out:
# 4913/4913 [==============================] - 10s 2ms/step
# <ipython-input-57-ccfb790f4210>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_classified = features_known.append(features_unknown)

# %% [markdown]
# Once again exploring the distribution of licit/illicit transaction in the dataset and the results are very comparable to the ones obtained with Random Forest and Logistic Regression

# %%
features_unknown['class'].hist()
features_unknown['class'].value_counts(normalize=True) * 100
# Out:
# 2    72.117935
# 1    27.882065
# Name: class, dtype: float64

# %%
X = features_known[tx_features+agg_features]
y = features_known['class']
# this is important
y = y.apply(lambda x: 0 if x == 2 else 1 )
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=117,shuffle=True)
#Create a validation set
X_train, X_val, y_train, y_val = train_test_split(X_train,y_train,test_size=0.15,random_state=117,shuffle=True)
print("X_train shape",X_train.shape)
print("X_test shape",X_test.shape)
print("X_val shape",X_val.shape)
print("X_test shape",X_test.shape)
print("y_train shape",y_train.shape)
print("y_test shape",y_test.shape)
print("y_val shape",y_val.shape)
# Out:
# X_train shape (27704, 165)
# X_test shape (13970, 165)
# X_val shape (4890, 165)
# X_test shape (13970, 165)
# y_train shape (27704,)
# y_test shape (13970,)
# y_val shape (4890,)

# %%
features_known['class'].hist()
features_known['class'].value_counts(normalize=True) * 100
# Out:
# 2    90.239241
# 1     9.760759
# Name: class, dtype: float64

# %% [markdown]
# ## Compare the obtained results

# %% [markdown]
# The following table contains all the results obtained with the classifiers above. Training on this kind of dataset, driven by time rather than class distribution, can produce different results in different training session.

# %%
compare.head(10)
# Out:
#                                  model  Precision  Recall  F1 Score  \
# 0        Random Forest Classifier (tx)      0.981   0.854     0.913
# 1  Random Forest Classifier (tx + agg)      0.994   0.888     0.938
# 2             Logistic Regression (tx)      0.910   0.725     0.807
# 3       Logistic Regression (tx + agg)      0.848   0.791     0.819
# 4            Dense neural network (tx)      0.969   0.754     0.848
# 5      Dense neural network (tx + agg)      0.962   0.861     0.909
#
#    M.A F1 Score
# 0         0.985
# 1         0.989
# 2         0.967
# 3         0.967
# 4         0.975
# 5         0.984

# %%
labels = compare['model'].to_numpy()

# %%
precision = compare['Precision'].to_numpy()
recall = compare['Recall'].to_numpy()
f1 = compare['F1 Score'].to_numpy()
maf1 = compare['M.A F1 Score'].to_numpy()

x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars
fig, ax = plt.subplots(figsize=(20, 7))
prec_rects = ax.bar(x - width/2, precision, width, label='Precision',color='#83f27b')
rec_rects = ax.bar(x + width/2, recall, width, label='Recall',color='#f27b83')
f1_rects = ax.bar(x - (3/2)*width, f1, width, label='F1 Score',color='#f2b37b')
MAf1_rects = ax.bar(x + (3/2)*width, maf1, width, label='M.A. F1 Score',color='#7b8bf2')

ax.set_ylabel('value 0-1')
ax.set_title('Final metrics by classifier')
ax.set_xticks(np.arange(0,len(labels),1))
ax.set_yticks(np.arange(0,1,0.05))
ax.set_xticklabels(labels=labels)
ax.legend()

plt.grid(True)
fig.tight_layout()
plt.show()

# %% [markdown]
# We can see in the  following table that the results obtained are in-line with the paper's result.

# %%
precision = compare['Precision'].to_numpy()
recall = compare['Recall'].to_numpy()
f1 = compare['F1 Score'].to_numpy()
maf1 = compare['M.A F1 Score'].to_numpy()

x = np.arange(len(labels))  # the label locations
width = 0.55  # the width of the bars
fig, ax = plt.subplots(figsize=(6, 10))
f1_rects = ax.bar(x, f1, width, label='F1 Score',color='#f2b37b')
MAf1_rects = ax.bar(x , maf1, width, label='M.A. F1 Score',color='#7b8bf2',bottom=f1)
prec_rects = ax.bar(x, precision, width, label='Precision',color='#83f27b',bottom=maf1 + f1)
rec_rects = ax.bar(x, recall, width, label='Recall',color='#f27b83',bottom=maf1 + f1 + precision)

ax.set_ylabel('value 0-1')
ax.set_title('Final metrics by classifier')
ax.set_xticks(np.arange(0,len(labels),1))
ax.set_yticks(np.arange(0,4,0.1))
ax.set_xticklabels(labels=labels)
ax.legend()

plt.xticks(rotation=90)
plt.grid(True)
fig.tight_layout()
plt.show()

# %% [markdown]
# Save the results for later use

# %%
compare.to_csv("elliptic_bitcoin_dataset_cont/1_result_elliptic.csv")
